# %% [markdown]
# # AI 201 Programming Assignment 1
# ## A* Algorithm Implementation
#
# Submitted by:
# Jan Lendl R. Uy, 2019-00312

# %%
# CONSTANTS

# Relative path to the input file
INPUT_FILE_PATH = "astar_in.txt"

# Set a maximum number of iterations for A* to avoid infinite 
# loop if there is no solution
MAX_A_STAR_ITERATIONS = 50000

# %% [markdown]
# ## File Handling
# This function reads an input .txt file containing the start and goal states of the puzzle then converts the puzzle contents into a two-dimensional tuple of tile values. The input file is stored in the same directory as the notebook file with the filename of "astar_in.txt".

# %%
def read_file(path):
    
    with open(path, "r") as file:
        lines = file.readlines()

    # Initialize lists to store the start state and goal state
    start_state = []
    goal_state = []

    # Initialize a flag to keep track if following tiles belong to the start
    # or the goal state
    reading_part = None

    for line in lines:
        line = line.strip() # Remove leading/trailing whitespace
        if line == "start":
            reading_part = "start"
        elif line == "goal":
            reading_part = "goal"
        elif line and reading_part:
            # Convert line into a list, handling "*" and converting numbers to integers
            line_list = [int(x) if x.isdigit() else x for x in line.split()]
            if reading_part == "start":
                start_state.append(line_list)
            elif reading_part == "goal":
                goal_state.append(line_list)
                
    start_state = tuple(tuple(row) for row in start_state)
    goal_state = tuple(tuple(row) for row in goal_state)

    return start_state, goal_state

# %%
start_state, goal_state = read_file(INPUT_FILE_PATH)
print(f"Start State: {start_state}")
print(f"Goal State: {goal_state}")
# Out:
# Start State: ((2, 1, 6), (4, '*', 8), (7, 5, 3))
# Goal State: ((1, 2, 3), (8, '*', 4), (7, 6, 5))

# %% [markdown]
# ## PuzzleBoard
# This class encapsulates the puzzle as a tuple of tuples (i.e. 2D tuple).
#
# Among the operators overridden in this class are the following:
# - `__str__` to "prettify" the printing of the 8-puzzle
# - `__eq__` and `__hash__` for checking of equal board contents
#
# Aside from this, the following helper methods are implemented to simplify the operations of the game:
# - `convert_board_to_string()` which reads the two-dimensional tuple representation of the puzzle and converts this into a prettier format
# - `_find_empty_tile()` which looks for the empty tile denoted by a "*" in the puzzle
# - `get_possible_moves()` which determines all of the possible moves of the empty tile based on its current position in the puzzle
#
# The heuristic functions are also found in this class as methods of the puzzle. These are:
# - `get_misplaced_tiles()` which, as its name implies, counts the number of misplaced in the current puzzle in reference to the goal puzzle state
# - `get_manhattan_distance()` which obtains the Manhattan Distance of each tile from its current position to its desired position
# - `get_nilsson_sequence_score()` which obtains the Nilsson Sequence Score by computing the sequence score multiplied by 3 and summed to the Manhattan Distance of each tile from the current position to the desired position
#
# It is worth noting that computing the Nilsson Sequence Score has a caveat. It is only designed to work for an 8-Puzzle. Other puzzle sizes will not work for this heuristic function programmed below.

# %%
class PuzzleBoard:
    
    def __init__(self, board):
        self.board = board
        
        # Assume that the puzzle is a square
        self.rows = len(board)
        self.cols = len(board[0])
        
        self.board_as_string = self.convert_board_to_string()
        
    def convert_board_to_string(self):
        if not self.board:
            return "Empty board"
        
        board = ""

        for i in range(self.rows):
            board += "| "
            for j in range(self.cols):
                tile = self.board[i][j]
                board += str(tile)
                board += " | "
            board += "\n"
            
        return board

    def __str__(self):
                    
        return self.board_as_string
    
    def __eq__(self, other):
        if not isinstance(other, PuzzleBoard):
            return False
        return self.board == other.board

    def __hash__(self):
        return hash(self.board)
    
    def _find_empty_tile(self):
        for i, row in enumerate(self.board):
            for j, tile in enumerate(row):
                if tile == "*":
                    return (i, j)
        raise ValueError("No empty tile found in the puzzle")
    
    def get_possible_moves(self):
        empty_row, empty_col = self._find_empty_tile()
        possible_moves = []
        
        # Possible moves: up, down, left, right
        # Tuples indicate the numbers added to the coordinates of the empty tile
        directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]
        
        for direction in directions:
            new_row = empty_row + direction[0]
            new_col = empty_col + direction[1]
            
            # Check if the new position is within the board
            if 0 <= new_row < len(self.board) and 0 <= new_col < len(self.board[0]):
                # Create a new board configuration with the move applied
                new_board = [list(row) for row in self.board]  # Convert tuple of tuples to list of lists
                new_board[empty_row][empty_col], new_board[new_row][new_col] = new_board[new_row][new_col], new_board[empty_row][empty_col]
                new_board = tuple(tuple(row) for row in new_board)  # Convert back to tuple of tuples
                
                possible_moves.append(new_board)
        
        return possible_moves
    
    # Helper methods useful for computing the different heuristic functions h(n)
    
    def get_misplaced_tiles(self, goal_puzzle):
        misplaced = 0
        goal_state = goal_puzzle.board
        for i in range(self.rows):
            for j in range(self.cols):
                if self.board[i][j] != "*" and self.board[i][j] != goal_state[i][j]:
                    misplaced += 1
        return misplaced
    
    def get_manhattan_distance(self, goal_puzzle):
        total_distance = 0
        goal_state = goal_puzzle.board

        for i in range(self.rows):
            for j in range(self.cols):
                if self.board[i][j] != "*":
                    # Find the tile's position in the goal state
                    for gi in range(self.rows):
                        for gj in range(self.cols):
                            if self.board[i][j] == goal_state[gi][gj]:
                                # Calculate Manhattan distance for this tile
                                distance = abs(i - gi) + abs(j - gj)
                                total_distance += distance
                                break
                        else:
                            continue
                        break

        return total_distance
    
    def get_nilsson_sequence_score(self, goal_puzzle):
        current_board = self.board
        goal_board = goal_puzzle.board

        manhattan_dist = self.get_manhattan_distance(goal_puzzle)
        
        # Flatten the boards for easier index computation
        current_board_flat = [tile for row in current_board for tile in row]
        goal_board_flat = [tile for row in goal_board for tile in row]
        
        # The correct clockwise ordering of the tiles
        goal_order = goal_board_flat[0:3] + [goal_board_flat[5], goal_board_flat[8], goal_board_flat[7], goal_board_flat[6], goal_board_flat[3]]
        current_order = current_board_flat[0:3] + [current_board_flat[5], current_board_flat[8], current_board_flat[7], current_board_flat[6], current_board_flat[3]]

        # Calculate sequence score
        goal_pairs = []
        current_pairs = []
        sequence_score = 0
        for i in range(-1, -len(goal_order), -1):
            current_pair = (current_order[i], current_order[i+1])
            goal_pair = (goal_order[i], goal_order[i+1])
            goal_pairs.append(goal_pair)
            if current_pair[0] == "*":
                continue
            current_pairs.append(current_pair)

        for pair in current_pairs:
            if pair not in goal_pairs:
                sequence_score += 2

        # Check the center square, add 1 if it is not the empty square
        if current_board_flat[4] != "*":
            sequence_score += 1
        
        # Multiply the sequence score by 3 and add the Manhattan distance
        return 3 * sequence_score + manhattan_dist, manhattan_dist, sequence_score

# %%
start_puzzle = PuzzleBoard(start_state)
goal_puzzle = PuzzleBoard(goal_state)
print(f"Start Puzzle: \n{start_puzzle}")
print(f"Goal Puzzle: \n{goal_puzzle}")
# Out:
# Start Puzzle:
# | 2 | 1 | 6 |
# | 4 | * | 8 |
# | 7 | 5 | 3 |
#
# Goal Puzzle:
# | 1 | 2 | 3 |
# | 8 | * | 4 |
# | 7 | 6 | 5 |

# %% [markdown]
# ## PuzzleSearchNode
# This class is used for instantiating a node that will be used in creating the search tree for A* search. It stores the following attributes:
# - `self.puzzle` stores the state
# - `self.parent` stores the predecessor node of the current node
# - `self.g`, `self.h`, and `self.f` store the path cost, estimated cost, and the total estimated cost, respectively
#
# Among the operators overridden in this class are the following:
# - `__lt__` that compares the "value" of two nodes based on the total estimated path cost f(n)
# - `__eq__` and `__hash__` for checking of equal node (i.e. similar board configuration)
#
# There are two methods that enable the heuristic search operations:
# - `expand()` calls the get_possible_moves() method of PuzzleBoard and creates node out of each possible state (i.e. puzzle configurations)
# - `compute_costs` is an update method for computing the estimated cost h(n) and the total estimated path cost f(n)

# %%
class PuzzleSearchNode:

    def __init__(self, puzzle, heuristic, g=0, parent=None):
        self.puzzle = puzzle
        self.parent = parent
        self.heuristic = heuristic
        self.g = g  # Path cost from start node to current node
        self.h = 0  # Heuristic estimate from current node to goal
        self.f = 0  # Total estimated path cost (g + h)
        
        self.p = 0 # Manhattan Distance, for the purpose of printing P(n) of Nilsson heuristic
        self.s = 0 # Sequence Score, for the purpose of printing S(n) of Nilsson heuristic

    def expand(self):
        expanded = []
        for new_puzzle in self.puzzle.get_possible_moves():
            child_path_cost = self.g + 1 # Increment path cost of child node by 1
            child_puzzle = PuzzleBoard(new_puzzle) # Initialize a new instance for each 8-puzzle state 
            child = PuzzleSearchNode(child_puzzle, self.heuristic, child_path_cost, self)
            expanded.append(child)
        return expanded

    def compute_costs(self, goal_node):
        goal_puzzle = goal_node.puzzle
        if self.heuristic == "misplaced":
            self.h = self.puzzle.get_misplaced_tiles(goal_puzzle)
        elif self.heuristic == "manhattan":
            self.h = self.puzzle.get_manhattan_distance(goal_puzzle)
        elif self.heuristic == "nilsson":
            self.h, self.p, self.s = self.puzzle.get_nilsson_sequence_score(goal_puzzle)
        self.f = self.g + self.h

    def goal_test(self, goal_node):
        return self == goal_node

    def __lt__(self, other):
        return self.f < other.f

    def __eq__(self, other):
        return isinstance(other, PuzzleSearchNode) and self.puzzle == other.puzzle

    def __hash__(self):
        return hash(self.puzzle)

# %% [markdown]
# ## A* Search
# Using the class definitions for the 8-Puzzle and the search node, the A* algorithm is implemented as shown below, following the same algorithm outlined in slide 21 of Lecture 3B.

# %%
def print_node_costs(node, search_cost, heuristic):
    print(f"f(n) = {node.f}, g(n) = {node.g}, h(n) = {node.h}")
    if heuristic == "nilsson":
        print(f"Nilsson heuristic-specific values: P(n) = {node.p}, S(n) = {node.s}")
    print(f"Cumulative search cost = {search_cost}")
    print(f"Current node:\n{node.puzzle}")

# %%
def astar_search(start_puzzle, goal_puzzle, heuristic="misplaced"):
    
    start_node = PuzzleSearchNode(start_puzzle, heuristic)
    goal_node = PuzzleSearchNode(goal_puzzle, heuristic)
    
    # Step 1: Compute initial costs for the start node
    start_node.compute_costs(goal_node)
    
    # Step 1: Initialize open list (and closed list)
    open_list = [start_node]
    closed_list = []
    
    search_cost = 0 # Keep track of search cost in terms of nodes generated

    # print(f"Initial estimated path cost f = {start_node.f}")
    
    for i in range(MAX_A_STAR_ITERATIONS):
        
        # Step 2: Terminate if open list is empty
        if len(open_list) == 0:
            return "Failed to find the goal node!"
        
        # Step 3: Find the node with the lowest f value
        # Remove this node from open list and then add to the closed list
        current_node = min(open_list)
        open_list.remove(current_node)
        closed_list.append(current_node)
                
        # Step 4: If the current node is the goal node, return the current node
        if current_node.goal_test(goal_node):
            print("Goal node found!")
            return i, search_cost, current_node
                
        # Step 5: Expand current node to get successor nodes
        # If no nodes from expansion, continue iteration
        expansion = current_node.expand()
        if len(expansion) < 1:
            print(f"Iteration {i+1}:")
            print_node_costs(current_node, search_cost, heuristic)
            continue
        
        search_cost += len(expansion) # Update search cost
                
        for successor_node in expansion:
            successor_node.compute_costs(goal_node)
            
            # Step 6 and 7: Handle successors
            existing_open_node = None
            existing_closed_node = None

            # Check if the successor node is in the open list
            if successor_node in open_list:
                existing_open_node = open_list[open_list.index(successor_node)]

            # Check if the successor node is in the closed list
            if successor_node in closed_list:
                existing_closed_node = closed_list[closed_list.index(successor_node)]
            
            if existing_open_node and existing_closed_node:
                # Node exists in both lists, use the one with lower f value
                if existing_open_node < existing_closed_node:
                    existing_node = existing_open_node
                else:
                    existing_node = existing_closed_node
            elif existing_open_node:
                existing_node = existing_open_node
            elif existing_closed_node:
                existing_node = existing_closed_node
            else:
                existing_node = None
            
            if existing_node:
                if successor_node < existing_node:
                    # Update the costs of existing node for the node with lower f
                    existing_node.g = successor_node.g
                    existing_node.f = successor_node.f
                    existing_node.parent = current_node
                    
                    # Move from closed list to open list if f values are lower
                    if existing_node in closed_list:
                        closed_list.remove(existing_node)
                        open_list.append(existing_node)
            else:
                # New node, add to open list
                open_list.append(successor_node)
        
        print(f"Iteration {i+1}:")
        print_node_costs(current_node, search_cost, heuristic)
        
    return f"Failed to find a solution within {MAX_A_STAR_ITERATIONS} iterations!"

def get_solution(goal_node):
    solution = [goal_node]
    current_node = goal_node
    while True:
        current_node = current_node.parent
        if current_node == None:
            break
        solution.append(current_node)
    solution.reverse()
    return solution

# %% [markdown]
# ### A* Search using Number of Misplaced Tiles as the Heuristic

# %%
iters_misplaced, search_cost_misplaced, result_misplaced = astar_search(start_puzzle, goal_puzzle)
print(f"Solution found for {iters_misplaced} iterations of A* search. The heuristic function is the number of misplaced tiles.")
print(f"Search cost: {search_cost_misplaced} nodes generated")
# Out:
# Iteration 1:
# f(n) = 7, g(n) = 0, h(n) = 7
# Cumulative search cost = 4
# Current node:
# | 2 | 1 | 6 |
# | 4 | * | 8 |
# | 7 | 5 | 3 |
#
# Iteration 2:
# f(n) = 8, g(n) = 1, h(n) = 7
# Cumulative search cost = 7
# Current node:
# | 2 | * | 6 |
# | 4 | 1 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 3:
# f(n) = 8, g(n) = 1, h(n) = 7
# Cumulative search cost = 10
# Current node:
# | 2 | 1 | 6 |
# | 4 | 5 | 8 |
# | 7 | * | 3 |
#
# Iteration 4:
# f(n) = 8, g(n) = 1, h(n) = 7
# Cumulative search cost = 13
# Current node:
# | 2 | 1 | 6 |
# | * | 4 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 5:
# f(n) = 8, g(n) = 1, h(n) = 7
# Cumulative search cost = 16
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | * |
# | 7 | 5 | 3 |
#
# Iteration 6:
# f(n) = 8, g(n) = 2, h(n) = 6
# Cumulative search cost = 18
# Current node:
# | * | 2 | 6 |
# | 4 | 1 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 7:
# f(n) = 9, g(n) = 2, h(n) = 7
# Cumulative search cost = 20
# Current node:
# | 2 | 6 | * |
# | 4 | 1 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 8:
# f(n) = 9, g(n) = 2, h(n) = 7
# Cumulative search cost = 22
# Current node:
# | 2 | 1 | 6 |
# | 4 | 5 | 8 |
# | 7 | 3 | * |
#
# Iteration 9:
# f(n) = 9, g(n) = 2, h(n) = 7
# Cumulative search cost = 24
# Current node:
# | * | 1 | 6 |
# | 2 | 4 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 10:
# f(n) = 9, g(n) = 2, h(n) = 7
# Cumulative search cost = 26
# Current node:
# | 2 | 1 | * |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 11:
# f(n) = 9, g(n) = 2, h(n) = 7
# Cumulative search cost = 28
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | 3 |
# | 7 | 5 | * |
#
# Iteration 12:
# f(n) = 9, g(n) = 3, h(n) = 6
# Cumulative search cost = 31
# Current node:
# | 4 | 2 | 6 |
# | * | 1 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 13:
# f(n) = 9, g(n) = 3, h(n) = 6
# Cumulative search cost = 34
# Current node:
# | 1 | * | 6 |
# | 2 | 4 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 14:
# f(n) = 9, g(n) = 3, h(n) = 6
# Cumulative search cost = 37
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | 3 |
# | 7 | * | 5 |
#
# Iteration 15:
# f(n) = 10, g(n) = 2, h(n) = 8
# Cumulative search cost = 39
# Current node:
# | 2 | 1 | 6 |
# | 4 | 5 | 8 |
# | * | 7 | 3 |
#
# Iteration 16:
# f(n) = 10, g(n) = 2, h(n) = 8
# Cumulative search cost = 41
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 8 |
# | * | 5 | 3 |
#
# Iteration 17:
# f(n) = 10, g(n) = 3, h(n) = 7
# Cumulative search cost = 44
# Current node:
# | 2 | 6 | 8 |
# | 4 | 1 | * |
# | 7 | 5 | 3 |
#
# Iteration 18:
# f(n) = 10, g(n) = 3, h(n) = 7
# Cumulative search cost = 47
# Current node:
# | 2 | 1 | 6 |
# | 4 | 5 | * |
# | 7 | 3 | 8 |
#
# Iteration 19:
# f(n) = 10, g(n) = 3, h(n) = 7
# Cumulative search cost = 50
# Current node:
# | 2 | * | 1 |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 20:
# f(n) = 10, g(n) = 4, h(n) = 6
# Cumulative search cost = 54
# Current node:
# | 4 | 2 | 6 |
# | 1 | * | 8 |
# | 7 | 5 | 3 |
#
# Iteration 21:
# f(n) = 10, g(n) = 4, h(n) = 6
# Cumulative search cost = 58
# Current node:
# | 1 | 4 | 6 |
# | 2 | * | 8 |
# | 7 | 5 | 3 |
#
# Iteration 22:
# f(n) = 10, g(n) = 4, h(n) = 6
# Cumulative search cost = 60
# Current node:
# | 1 | 6 | * |
# | 2 | 4 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 23:
# f(n) = 10, g(n) = 4, h(n) = 6
# Cumulative search cost = 64
# Current node:
# | 2 | 1 | 6 |
# | 4 | * | 3 |
# | 7 | 8 | 5 |
#
# Iteration 24:
# f(n) = 10, g(n) = 4, h(n) = 6
# Cumulative search cost = 66
# Current node:
# | * | 2 | 1 |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 25:
# f(n) = 11, g(n) = 4, h(n) = 7
# Cumulative search cost = 68
# Current node:
# | 4 | 2 | 6 |
# | 7 | 1 | 8 |
# | * | 5 | 3 |
#
# Iteration 26:
# f(n) = 11, g(n) = 4, h(n) = 7
# Cumulative search cost = 70
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | 3 |
# | * | 7 | 5 |
#
# Iteration 27:
# f(n) = 11, g(n) = 3, h(n) = 8
# Cumulative search cost = 73
# Current node:
# | 2 | 1 | 6 |
# | * | 5 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 28:
# f(n) = 11, g(n) = 3, h(n) = 8
# Cumulative search cost = 76
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 8 |
# | 5 | * | 3 |
#
# Iteration 29:
# f(n) = 11, g(n) = 4, h(n) = 7
# Cumulative search cost = 78
# Current node:
# | 2 | 6 | 8 |
# | 4 | 1 | 3 |
# | 7 | 5 | * |
#
# Iteration 30:
# f(n) = 11, g(n) = 4, h(n) = 7
# Cumulative search cost = 82
# Current node:
# | 2 | 6 | 8 |
# | 4 | * | 1 |
# | 7 | 5 | 3 |
#
# Iteration 31:
# f(n) = 11, g(n) = 4, h(n) = 7
# Cumulative search cost = 84
# Current node:
# | 2 | 1 | * |
# | 4 | 5 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 32:
# f(n) = 11, g(n) = 4, h(n) = 7
# Cumulative search cost = 88
# Current node:
# | 2 | 1 | 6 |
# | 4 | * | 5 |
# | 7 | 3 | 8 |
#
# Iteration 33:
# f(n) = 11, g(n) = 4, h(n) = 7
# Cumulative search cost = 92
# Current node:
# | 2 | 8 | 1 |
# | 4 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 34:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 95
# Current node:
# | 4 | 2 | 6 |
# | 1 | 5 | 8 |
# | 7 | * | 3 |
#
# Iteration 35:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 98
# Current node:
# | 4 | 2 | 6 |
# | 1 | 8 | * |
# | 7 | 5 | 3 |
#
# Iteration 36:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 101
# Current node:
# | 1 | 4 | 6 |
# | 2 | 5 | 8 |
# | 7 | * | 3 |
#
# Iteration 37:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 104
# Current node:
# | 1 | 4 | 6 |
# | * | 2 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 38:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 107
# Current node:
# | 1 | 4 | 6 |
# | 2 | 8 | * |
# | 7 | 5 | 3 |
#
# Iteration 39:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 110
# Current node:
# | 1 | 6 | 8 |
# | 2 | 4 | * |
# | 7 | 5 | 3 |
#
# Iteration 40:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 113
# Current node:
# | 2 | * | 6 |
# | 4 | 1 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 41:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 116
# Current node:
# | 2 | 1 | 6 |
# | * | 4 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 42:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 119
# Current node:
# | 2 | 1 | 6 |
# | 4 | 3 | * |
# | 7 | 8 | 5 |
#
# Iteration 43:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 122
# Current node:
# | 4 | 2 | 1 |
# | * | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 44:
# f(n) = 11, g(n) = 5, h(n) = 6
# Cumulative search cost = 125
# Current node:
# | 2 | 6 | 8 |
# | 4 | 1 | 3 |
# | 7 | * | 5 |
#
# Iteration 45:
# f(n) = 11, g(n) = 6, h(n) = 5
# Cumulative search cost = 129
# Current node:
# | 1 | 6 | 8 |
# | 2 | * | 4 |
# | 7 | 5 | 3 |
#
# Iteration 46:
# f(n) = 11, g(n) = 6, h(n) = 5
# Cumulative search cost = 131
# Current node:
# | * | 2 | 6 |
# | 4 | 1 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 47:
# f(n) = 11, g(n) = 6, h(n) = 5
# Cumulative search cost = 135
# Current node:
# | 4 | 2 | 1 |
# | 8 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 48:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 138
# Current node:
# | 4 | * | 6 |
# | 1 | 2 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 49:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 141
# Current node:
# | 4 | 2 | 6 |
# | 7 | 1 | 8 |
# | 5 | * | 3 |
#
# Iteration 50:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 144
# Current node:
# | 2 | 1 | 6 |
# | * | 8 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 51:
# f(n) = 12, g(n) = 4, h(n) = 8
# Cumulative search cost = 146
# Current node:
# | * | 1 | 6 |
# | 2 | 5 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 52:
# f(n) = 12, g(n) = 4, h(n) = 8
# Cumulative search cost = 150
# Current node:
# | 2 | 1 | 6 |
# | 5 | * | 8 |
# | 4 | 7 | 3 |
#
# Iteration 53:
# f(n) = 12, g(n) = 4, h(n) = 8
# Cumulative search cost = 154
# Current node:
# | 2 | 1 | 6 |
# | 7 | * | 8 |
# | 5 | 4 | 3 |
#
# Iteration 54:
# f(n) = 12, g(n) = 4, h(n) = 8
# Cumulative search cost = 156
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 8 |
# | 5 | 3 | * |
#
# Iteration 55:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 159
# Current node:
# | 2 | * | 8 |
# | 4 | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 56:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 162
# Current node:
# | 2 | 6 | 8 |
# | 4 | 5 | 1 |
# | 7 | * | 3 |
#
# Iteration 57:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 165
# Current node:
# | 2 | 6 | 8 |
# | * | 4 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 58:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 168
# Current node:
# | 2 | * | 1 |
# | 4 | 5 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 59:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 171
# Current node:
# | 2 | * | 6 |
# | 4 | 1 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 60:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 174
# Current node:
# | 2 | 1 | 6 |
# | 4 | 3 | 5 |
# | 7 | * | 8 |
#
# Iteration 61:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 177
# Current node:
# | 2 | 1 | 6 |
# | * | 4 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 62:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 180
# Current node:
# | 2 | 8 | 1 |
# | 4 | 5 | 6 |
# | 7 | * | 3 |
#
# Iteration 63:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 183
# Current node:
# | 2 | 8 | 1 |
# | * | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 64:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 186
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | * |
# | 7 | 5 | 3 |
#
# Iteration 65:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 188
# Current node:
# | 4 | 2 | 6 |
# | 1 | 5 | 8 |
# | 7 | 3 | * |
#
# Iteration 66:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 190
# Current node:
# | 4 | 2 | * |
# | 1 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 67:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 192
# Current node:
# | 4 | 2 | 6 |
# | 1 | 8 | 3 |
# | 7 | 5 | * |
#
# Iteration 68:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 194
# Current node:
# | 1 | 4 | 6 |
# | 2 | 5 | 8 |
# | 7 | 3 | * |
#
# Iteration 69:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 196
# Current node:
# | 1 | 4 | * |
# | 2 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 70:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 198
# Current node:
# | 1 | 4 | 6 |
# | 2 | 8 | 3 |
# | 7 | 5 | * |
#
# Iteration 71:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 200
# Current node:
# | 1 | 6 | 8 |
# | 2 | 4 | 3 |
# | 7 | 5 | * |
#
# Iteration 72:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 202
# Current node:
# | 2 | 6 | * |
# | 4 | 1 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 73:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 204
# Current node:
# | * | 1 | 6 |
# | 2 | 4 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 74:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 206
# Current node:
# | 2 | 1 | * |
# | 4 | 3 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 75:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 210
# Current node:
# | 2 | 6 | 8 |
# | 4 | * | 3 |
# | 7 | 1 | 5 |
#
# Iteration 76:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 213
# Current node:
# | 1 | * | 8 |
# | 2 | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 77:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 216
# Current node:
# | 1 | 6 | 8 |
# | 2 | 5 | 4 |
# | 7 | * | 3 |
#
# Iteration 78:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 219
# Current node:
# | 1 | 6 | 8 |
# | * | 2 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 79:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 222
# Current node:
# | 4 | 2 | 6 |
# | * | 1 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 80:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 225
# Current node:
# | 4 | 2 | 1 |
# | 8 | 5 | 6 |
# | 7 | * | 3 |
#
# Iteration 81:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 228
# Current node:
# | 4 | 2 | 1 |
# | 8 | 6 | * |
# | 7 | 5 | 3 |
#
# Iteration 82:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 232
# Current node:
# | 2 | 1 | 6 |
# | 8 | * | 3 |
# | 4 | 7 | 5 |
#
# Iteration 83:
# f(n) = 12, g(n) = 5, h(n) = 7
# Cumulative search cost = 235
# Current node:
# | 1 | * | 6 |
# | 2 | 5 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 84:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 237
# Current node:
# | * | 2 | 8 |
# | 4 | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 85:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 239
# Current node:
# | * | 2 | 1 |
# | 4 | 5 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 86:
# f(n) = 12, g(n) = 6, h(n) = 6
# Cumulative search cost = 241
# Current node:
# | * | 2 | 6 |
# | 4 | 1 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 87:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 244
# Current node:
# | 4 | 2 | 6 |
# | 1 | 8 | 3 |
# | 7 | * | 5 |
#
# Iteration 88:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 247
# Current node:
# | 1 | 4 | 6 |
# | 2 | 8 | 3 |
# | 7 | * | 5 |
#
# Iteration 89:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 250
# Current node:
# | 1 | 6 | 8 |
# | 2 | 4 | 3 |
# | 7 | * | 5 |
#
# Iteration 90:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 253
# Current node:
# | 2 | 6 | 3 |
# | 4 | 1 | * |
# | 7 | 8 | 5 |
#
# Iteration 91:
# f(n) = 12, g(n) = 7, h(n) = 5
# Cumulative search cost = 256
# Current node:
# | 1 | * | 6 |
# | 2 | 4 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 92:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 258
# Current node:
# | 4 | 2 | 6 |
# | 1 | 5 | 8 |
# | * | 7 | 3 |
#
# Iteration 93:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 260
# Current node:
# | 1 | 4 | 6 |
# | 2 | 5 | 8 |
# | * | 7 | 3 |
#
# Iteration 94:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 262
# Current node:
# | * | 4 | 6 |
# | 1 | 2 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 95:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 264
# Current node:
# | 1 | 4 | 6 |
# | 7 | 2 | 8 |
# | * | 5 | 3 |
#
# Iteration 96:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 266
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 3 |
# | * | 8 | 5 |
#
# Iteration 97:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 268
# Current node:
# | 2 | 1 | 6 |
# | 4 | 3 | 5 |
# | 7 | 8 | * |
#
# Iteration 98:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 270
# Current node:
# | 4 | 2 | 1 |
# | 7 | 8 | 6 |
# | * | 5 | 3 |
#
# Iteration 99:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 272
# Current node:
# | 2 | 6 | 8 |
# | 4 | 1 | 3 |
# | * | 7 | 5 |
#
# Iteration 100:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 275
# Current node:
# | 4 | * | 1 |
# | 8 | 2 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 101:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 277
# Current node:
# | 4 | 6 | * |
# | 1 | 2 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 102:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 281
# Current node:
# | 4 | 2 | 6 |
# | 7 | * | 8 |
# | 5 | 1 | 3 |
#
# Iteration 103:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 283
# Current node:
# | 4 | 2 | 6 |
# | 7 | 1 | 8 |
# | 5 | 3 | * |
#
# Iteration 104:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 285
# Current node:
# | * | 1 | 6 |
# | 2 | 8 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 105:
# f(n) = 13, g(n) = 5, h(n) = 8
# Cumulative search cost = 288
# Current node:
# | 2 | * | 6 |
# | 5 | 1 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 106:
# f(n) = 13, g(n) = 5, h(n) = 8
# Cumulative search cost = 291
# Current node:
# | 2 | 1 | 6 |
# | 5 | 7 | 8 |
# | 4 | * | 3 |
#
# Iteration 107:
# f(n) = 13, g(n) = 5, h(n) = 8
# Cumulative search cost = 294
# Current node:
# | 2 | 1 | 6 |
# | 5 | 8 | * |
# | 4 | 7 | 3 |
#
# Iteration 108:
# f(n) = 13, g(n) = 5, h(n) = 8
# Cumulative search cost = 297
# Current node:
# | 2 | * | 6 |
# | 7 | 1 | 8 |
# | 5 | 4 | 3 |
#
# Iteration 109:
# f(n) = 13, g(n) = 5, h(n) = 8
# Cumulative search cost = 300
# Current node:
# | 2 | 1 | 6 |
# | * | 7 | 8 |
# | 5 | 4 | 3 |
#
# Iteration 110:
# f(n) = 13, g(n) = 5, h(n) = 8
# Cumulative search cost = 303
# Current node:
# | 2 | 1 | 6 |
# | 7 | 8 | * |
# | 5 | 4 | 3 |
#
# Iteration 111:
# f(n) = 13, g(n) = 5, h(n) = 8
# Cumulative search cost = 306
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | * |
# | 5 | 3 | 8 |
#
# Iteration 112:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 308
# Current node:
# | 2 | 8 | * |
# | 4 | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 113:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 310
# Current node:
# | 2 | 6 | 8 |
# | 4 | 5 | 1 |
# | 7 | 3 | * |
#
# Iteration 114:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 312
# Current node:
# | * | 6 | 8 |
# | 2 | 4 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 115:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 316
# Current node:
# | 2 | 5 | 1 |
# | 4 | * | 6 |
# | 7 | 3 | 8 |
#
# Iteration 116:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 318
# Current node:
# | 2 | 6 | * |
# | 4 | 1 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 117:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 320
# Current node:
# | * | 1 | 6 |
# | 2 | 4 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 118:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 322
# Current node:
# | 2 | 8 | 1 |
# | 4 | 5 | 6 |
# | 7 | 3 | * |
#
# Iteration 119:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 324
# Current node:
# | * | 8 | 1 |
# | 2 | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 120:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 326
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | 5 | * |
#
# Iteration 121:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 329
# Current node:
# | 4 | 2 | 6 |
# | 1 | 5 | * |
# | 7 | 3 | 8 |
#
# Iteration 122:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 332
# Current node:
# | 1 | 4 | 6 |
# | 2 | 5 | * |
# | 7 | 3 | 8 |
#
# Iteration 123:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 335
# Current node:
# | 1 | * | 4 |
# | 2 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 124:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 338
# Current node:
# | 2 | * | 1 |
# | 4 | 3 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 125:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 341
# Current node:
# | 2 | * | 8 |
# | 4 | 6 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 126:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 344
# Current node:
# | 2 | 6 | 8 |
# | * | 4 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 127:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 347
# Current node:
# | 2 | 6 | 8 |
# | 4 | 3 | * |
# | 7 | 1 | 5 |
#
# Iteration 128:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 349
# Current node:
# | 1 | 8 | * |
# | 2 | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 129:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 351
# Current node:
# | 1 | 6 | 8 |
# | 2 | 5 | 4 |
# | 7 | 3 | * |
#
# Iteration 130:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 355
# Current node:
# | 4 | 2 | 6 |
# | 1 | * | 3 |
# | 7 | 8 | 5 |
#
# Iteration 131:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 357
# Current node:
# | 4 | 2 | 1 |
# | 8 | 5 | 6 |
# | 7 | 3 | * |
#
# Iteration 132:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 359
# Current node:
# | 4 | 2 | * |
# | 8 | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 133:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 361
# Current node:
# | 4 | 2 | 1 |
# | 8 | 6 | 3 |
# | 7 | 5 | * |
#
# Iteration 134:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 364
# Current node:
# | 2 | * | 6 |
# | 8 | 1 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 135:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 367
# Current node:
# | 2 | 1 | 6 |
# | 8 | 7 | 3 |
# | 4 | * | 5 |
#
# Iteration 136:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 370
# Current node:
# | 2 | 1 | 6 |
# | 8 | 3 | * |
# | 4 | 7 | 5 |
#
# Iteration 137:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 374
# Current node:
# | 1 | 5 | 6 |
# | 2 | * | 8 |
# | 4 | 7 | 3 |
#
# Iteration 138:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 376
# Current node:
# | 1 | 6 | * |
# | 2 | 5 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 139:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 379
# Current node:
# | 4 | 2 | 8 |
# | * | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 140:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 382
# Current node:
# | 4 | 2 | 1 |
# | * | 5 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 141:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 385
# Current node:
# | 4 | 2 | 6 |
# | * | 1 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 142:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 389
# Current node:
# | 1 | 4 | 6 |
# | 2 | * | 3 |
# | 7 | 8 | 5 |
#
# Iteration 143:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 393
# Current node:
# | 1 | 6 | 8 |
# | 2 | * | 3 |
# | 7 | 4 | 5 |
#
# Iteration 144:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 397
# Current node:
# | 2 | 6 | 3 |
# | 4 | * | 1 |
# | 7 | 8 | 5 |
#
# Iteration 145:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 399
# Current node:
# | 1 | 6 | * |
# | 2 | 4 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 146:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 402
# Current node:
# | 1 | * | 6 |
# | 2 | 8 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 147:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 404
# Current node:
# | * | 2 | 6 |
# | 5 | 1 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 148:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 406
# Current node:
# | * | 2 | 6 |
# | 7 | 1 | 8 |
# | 5 | 4 | 3 |
#
# Iteration 149:
# f(n) = 13, g(n) = 6, h(n) = 7
# Cumulative search cost = 410
# Current node:
# | 2 | 1 | 6 |
# | 7 | * | 4 |
# | 5 | 3 | 8 |
#
# Iteration 150:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 413
# Current node:
# | 1 | * | 6 |
# | 2 | 4 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 151:
# f(n) = 13, g(n) = 7, h(n) = 6
# Cumulative search cost = 416
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | * | 5 |
#
# Iteration 152:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 418
# Current node:
# | * | 2 | 1 |
# | 4 | 3 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 153:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 420
# Current node:
# | * | 2 | 8 |
# | 4 | 6 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 154:
# f(n) = 13, g(n) = 9, h(n) = 4
# Cumulative search cost = 423
# Current node:
# | 4 | 2 | 1 |
# | 8 | 6 | 3 |
# | 7 | * | 5 |
#
# Iteration 155:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 425
# Current node:
# | * | 2 | 6 |
# | 8 | 1 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 156:
# f(n) = 13, g(n) = 9, h(n) = 4
# Cumulative search cost = 428
# Current node:
# | 1 | 6 | 3 |
# | 2 | 4 | * |
# | 7 | 8 | 5 |
#
# Iteration 157:
# f(n) = 13, g(n) = 8, h(n) = 5
# Cumulative search cost = 432
# Current node:
# | 2 | 8 | 1 |
# | 4 | * | 3 |
# | 7 | 6 | 5 |
#
# Iteration 158:
# f(n) = 13, g(n) = 10, h(n) = 3
# Cumulative search cost = 436
# Current node:
# | 4 | 2 | 1 |
# | 8 | * | 3 |
# | 7 | 6 | 5 |
#
# Iteration 159:
# f(n) = 13, g(n) = 10, h(n) = 3
# Cumulative search cost = 440
# Current node:
# | 1 | 6 | 3 |
# | 2 | * | 4 |
# | 7 | 8 | 5 |
#
# Iteration 160:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 442
# Current node:
# | 2 | 6 | 8 |
# | 4 | 5 | 1 |
# | * | 7 | 3 |
#
# Iteration 161:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 444
# Current node:
# | 2 | 6 | 8 |
# | 7 | 4 | 1 |
# | * | 5 | 3 |
#
# Iteration 162:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 446
# Current node:
# | 2 | 1 | 6 |
# | 4 | 3 | 5 |
# | * | 7 | 8 |
#
# Iteration 163:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 448
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 5 |
# | * | 3 | 8 |
#
# Iteration 164:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 450
# Current node:
# | 2 | 8 | 1 |
# | 4 | 5 | 6 |
# | * | 7 | 3 |
#
# Iteration 165:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 452
# Current node:
# | 2 | 8 | 1 |
# | 7 | 4 | 6 |
# | * | 5 | 3 |
#
# Iteration 166:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 455
# Current node:
# | 4 | * | 2 |
# | 1 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 167:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 457
# Current node:
# | * | 1 | 8 |
# | 2 | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 168:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 459
# Current node:
# | 1 | 6 | 8 |
# | 2 | 5 | 4 |
# | * | 7 | 3 |
#
# Iteration 169:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 461
# Current node:
# | * | 6 | 8 |
# | 1 | 2 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 170:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 463
# Current node:
# | 1 | 6 | 8 |
# | 7 | 2 | 4 |
# | * | 5 | 3 |
#
# Iteration 171:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 465
# Current node:
# | 4 | 2 | 6 |
# | 7 | 1 | 3 |
# | * | 8 | 5 |
#
# Iteration 172:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 467
# Current node:
# | 4 | 2 | 1 |
# | 8 | 5 | 6 |
# | * | 7 | 3 |
#
# Iteration 173:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 469
# Current node:
# | 4 | 2 | 6 |
# | 1 | 8 | 3 |
# | * | 7 | 5 |
#
# Iteration 174:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 471
# Current node:
# | 1 | 4 | 6 |
# | 2 | 8 | 3 |
# | * | 7 | 5 |
#
# Iteration 175:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 473
# Current node:
# | 1 | 6 | 8 |
# | 2 | 4 | 3 |
# | * | 7 | 5 |
#
# Iteration 176:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 475
# Current node:
# | 2 | 6 | 3 |
# | 4 | 1 | 5 |
# | 7 | 8 | * |
#
# Iteration 177:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 478
# Current node:
# | 4 | 2 | 6 |
# | * | 5 | 8 |
# | 1 | 7 | 3 |
#
# Iteration 178:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 481
# Current node:
# | 1 | 4 | 6 |
# | * | 5 | 8 |
# | 2 | 7 | 3 |
#
# Iteration 179:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 484
# Current node:
# | 1 | 4 | 6 |
# | 7 | 2 | 8 |
# | 5 | * | 3 |
#
# Iteration 180:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 487
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 3 |
# | 8 | * | 5 |
#
# Iteration 181:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 490
# Current node:
# | 4 | 2 | 1 |
# | 7 | 8 | 6 |
# | 5 | * | 3 |
#
# Iteration 182:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 493
# Current node:
# | 2 | 6 | 8 |
# | * | 1 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 183:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 495
# Current node:
# | * | 4 | 1 |
# | 8 | 2 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 184:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 497
# Current node:
# | 4 | 1 | * |
# | 8 | 2 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 185:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 500
# Current node:
# | 4 | 6 | 8 |
# | 1 | 2 | * |
# | 7 | 5 | 3 |
#
# Iteration 186:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 503
# Current node:
# | 4 | 2 | 6 |
# | * | 7 | 8 |
# | 5 | 1 | 3 |
#
# Iteration 187:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 506
# Current node:
# | 4 | 2 | 6 |
# | 7 | 8 | * |
# | 5 | 1 | 3 |
#
# Iteration 188:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 509
# Current node:
# | 4 | 2 | 6 |
# | 7 | 1 | * |
# | 5 | 3 | 8 |
#
# Iteration 189:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 511
# Current node:
# | 2 | 6 | * |
# | 5 | 1 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 190:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 513
# Current node:
# | 2 | 1 | 6 |
# | 5 | 7 | 8 |
# | * | 4 | 3 |
#
# Iteration 191:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 515
# Current node:
# | 2 | 1 | 6 |
# | 5 | 7 | 8 |
# | 4 | 3 | * |
#
# Iteration 192:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 517
# Current node:
# | 2 | 1 | * |
# | 5 | 8 | 6 |
# | 4 | 7 | 3 |
#
# Iteration 193:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 519
# Current node:
# | 2 | 1 | 6 |
# | 5 | 8 | 3 |
# | 4 | 7 | * |
#
# Iteration 194:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 521
# Current node:
# | 2 | 6 | * |
# | 7 | 1 | 8 |
# | 5 | 4 | 3 |
#
# Iteration 195:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 523
# Current node:
# | * | 1 | 6 |
# | 2 | 7 | 8 |
# | 5 | 4 | 3 |
#
# Iteration 196:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 525
# Current node:
# | 2 | 1 | * |
# | 7 | 8 | 6 |
# | 5 | 4 | 3 |
#
# Iteration 197:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 527
# Current node:
# | 2 | 1 | 6 |
# | 7 | 8 | 3 |
# | 5 | 4 | * |
#
# Iteration 198:
# f(n) = 14, g(n) = 6, h(n) = 8
# Cumulative search cost = 529
# Current node:
# | 2 | 1 | * |
# | 7 | 4 | 6 |
# | 5 | 3 | 8 |
#
# Iteration 199:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 532
# Current node:
# | 2 | 6 | 8 |
# | 4 | 5 | * |
# | 7 | 3 | 1 |
#
# Iteration 200:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 535
# Current node:
# | 6 | * | 8 |
# | 2 | 4 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 201:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 538
# Current node:
# | 2 | 5 | 1 |
# | 4 | 3 | 6 |
# | 7 | * | 8 |
#
# Iteration 202:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 541
# Current node:
# | 2 | 5 | 1 |
# | * | 4 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 203:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 544
# Current node:
# | 2 | 5 | 1 |
# | 4 | 6 | * |
# | 7 | 3 | 8 |
#
# Iteration 204:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 547
# Current node:
# | 2 | 6 | 5 |
# | 4 | 1 | * |
# | 7 | 3 | 8 |
#
# Iteration 205:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 550
# Current node:
# | 2 | 8 | 1 |
# | 4 | 5 | * |
# | 7 | 3 | 6 |
#
# Iteration 206:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 553
# Current node:
# | 8 | * | 1 |
# | 2 | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 207:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 555
# Current node:
# | 4 | 2 | * |
# | 1 | 5 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 208:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 559
# Current node:
# | 4 | 2 | 6 |
# | 1 | * | 5 |
# | 7 | 3 | 8 |
#
# Iteration 209:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 561
# Current node:
# | 1 | 4 | * |
# | 2 | 5 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 210:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 565
# Current node:
# | 1 | 4 | 6 |
# | 2 | * | 5 |
# | 7 | 3 | 8 |
#
# Iteration 211:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 569
# Current node:
# | 1 | 8 | 4 |
# | 2 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 212:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 573
# Current node:
# | 2 | 3 | 1 |
# | 4 | * | 6 |
# | 7 | 8 | 5 |
#
# Iteration 213:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 575
# Current node:
# | 2 | 8 | * |
# | 4 | 6 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 214:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 577
# Current node:
# | * | 6 | 8 |
# | 2 | 4 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 215:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 579
# Current node:
# | 2 | 6 | * |
# | 4 | 3 | 8 |
# | 7 | 1 | 5 |
#
# Iteration 216:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 582
# Current node:
# | 4 | 2 | 6 |
# | 1 | 3 | * |
# | 7 | 8 | 5 |
#
# Iteration 217:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 585
# Current node:
# | 4 | 2 | 1 |
# | 8 | 5 | * |
# | 7 | 3 | 6 |
#
# Iteration 218:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 587
# Current node:
# | 2 | 6 | * |
# | 8 | 1 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 219:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 589
# Current node:
# | 2 | 1 | 6 |
# | 8 | 7 | 3 |
# | * | 4 | 5 |
#
# Iteration 220:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 591
# Current node:
# | 2 | 1 | * |
# | 8 | 3 | 6 |
# | 4 | 7 | 5 |
#
# Iteration 221:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 594
# Current node:
# | 1 | 5 | 6 |
# | 2 | 7 | 8 |
# | 4 | * | 3 |
#
# Iteration 222:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 597
# Current node:
# | 1 | 5 | 6 |
# | * | 2 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 223:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 600
# Current node:
# | 1 | 5 | 6 |
# | 2 | 8 | * |
# | 4 | 7 | 3 |
#
# Iteration 224:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 603
# Current node:
# | 1 | 6 | 8 |
# | 2 | 5 | * |
# | 4 | 7 | 3 |
#
# Iteration 225:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 607
# Current node:
# | 4 | 2 | 8 |
# | 6 | * | 1 |
# | 7 | 5 | 3 |
#
# Iteration 226:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 611
# Current node:
# | 4 | 2 | 1 |
# | 5 | * | 6 |
# | 7 | 3 | 8 |
#
# Iteration 227:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 614
# Current node:
# | 1 | 4 | 6 |
# | * | 2 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 228:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 617
# Current node:
# | 1 | 4 | 6 |
# | 2 | 3 | * |
# | 7 | 8 | 5 |
#
# Iteration 229:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 620
# Current node:
# | 1 | * | 8 |
# | 2 | 6 | 3 |
# | 7 | 4 | 5 |
#
# Iteration 230:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 623
# Current node:
# | 1 | 6 | 8 |
# | * | 2 | 3 |
# | 7 | 4 | 5 |
#
# Iteration 231:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 626
# Current node:
# | 1 | 6 | 8 |
# | 2 | 3 | * |
# | 7 | 4 | 5 |
#
# Iteration 232:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 629
# Current node:
# | 2 | * | 3 |
# | 4 | 6 | 1 |
# | 7 | 8 | 5 |
#
# Iteration 233:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 632
# Current node:
# | 2 | 6 | 3 |
# | 4 | 8 | 1 |
# | 7 | * | 5 |
#
# Iteration 234:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 635
# Current node:
# | 2 | 6 | 3 |
# | * | 4 | 1 |
# | 7 | 8 | 5 |
#
# Iteration 235:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 639
# Current node:
# | 1 | 8 | 6 |
# | 2 | * | 3 |
# | 4 | 7 | 5 |
#
# Iteration 236:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 641
# Current node:
# | 1 | 6 | * |
# | 2 | 8 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 237:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 644
# Current node:
# | 5 | 2 | 6 |
# | * | 1 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 238:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 647
# Current node:
# | 7 | 2 | 6 |
# | * | 1 | 8 |
# | 5 | 4 | 3 |
#
# Iteration 239:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 650
# Current node:
# | 2 | * | 6 |
# | 7 | 1 | 4 |
# | 5 | 3 | 8 |
#
# Iteration 240:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 653
# Current node:
# | 2 | 1 | 6 |
# | 7 | 3 | 4 |
# | 5 | * | 8 |
#
# Iteration 241:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 656
# Current node:
# | 2 | 1 | 6 |
# | * | 7 | 4 |
# | 5 | 3 | 8 |
#
# Iteration 242:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 658
# Current node:
# | 1 | 6 | * |
# | 2 | 4 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 243:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 661
# Current node:
# | 4 | 2 | 1 |
# | * | 3 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 244:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 664
# Current node:
# | 4 | 2 | 8 |
# | * | 6 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 245:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 667
# Current node:
# | 2 | * | 1 |
# | 4 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 246:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 670
# Current node:
# | 2 | 8 | 1 |
# | * | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 247:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 673
# Current node:
# | 2 | 8 | 1 |
# | 4 | 3 | * |
# | 7 | 6 | 5 |
#
# Iteration 248:
# f(n) = 14, g(n) = 11, h(n) = 3
# Cumulative search cost = 676
# Current node:
# | 4 | 2 | 1 |
# | 8 | 3 | * |
# | 7 | 6 | 5 |
#
# Iteration 249:
# f(n) = 14, g(n) = 11, h(n) = 3
# Cumulative search cost = 679
# Current node:
# | 1 | * | 3 |
# | 2 | 6 | 4 |
# | 7 | 8 | 5 |
#
# Iteration 250:
# f(n) = 14, g(n) = 11, h(n) = 3
# Cumulative search cost = 682
# Current node:
# | 1 | 6 | 3 |
# | 2 | 8 | 4 |
# | 7 | * | 5 |
#
# Iteration 251:
# f(n) = 14, g(n) = 11, h(n) = 3
# Cumulative search cost = 685
# Current node:
# | 1 | 6 | 3 |
# | * | 2 | 4 |
# | 7 | 8 | 5 |
#
# Iteration 252:
# f(n) = 14, g(n) = 7, h(n) = 7
# Cumulative search cost = 688
# Current node:
# | 1 | * | 6 |
# | 2 | 7 | 8 |
# | 5 | 4 | 3 |
#
# Iteration 253:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 691
# Current node:
# | 2 | 8 | 3 |
# | 4 | 6 | * |
# | 7 | 1 | 5 |
#
# Iteration 254:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 694
# Current node:
# | 2 | 6 | 3 |
# | 8 | 1 | * |
# | 4 | 7 | 5 |
#
# Iteration 255:
# f(n) = 14, g(n) = 10, h(n) = 4
# Cumulative search cost = 696
# Current node:
# | * | 2 | 3 |
# | 4 | 6 | 1 |
# | 7 | 8 | 5 |
#
# Iteration 256:
# f(n) = 14, g(n) = 9, h(n) = 5
# Cumulative search cost = 699
# Current node:
# | 1 | 6 | 3 |
# | 2 | 8 | * |
# | 4 | 7 | 5 |
#
# Iteration 257:
# f(n) = 14, g(n) = 8, h(n) = 6
# Cumulative search cost = 701
# Current node:
# | * | 2 | 6 |
# | 7 | 1 | 4 |
# | 5 | 3 | 8 |
#
# Iteration 258:
# f(n) = 14, g(n) = 10, h(n) = 4
# Cumulative search cost = 703
# Current node:
# | * | 2 | 1 |
# | 4 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 259:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 706
# Current node:
# | 4 | * | 6 |
# | 7 | 2 | 8 |
# | 5 | 1 | 3 |
#
# Iteration 260:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 708
# Current node:
# | * | 1 | 4 |
# | 2 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 261:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 710
# Current node:
# | 2 | 6 | 8 |
# | 7 | 4 | 3 |
# | * | 1 | 5 |
#
# Iteration 262:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 712
# Current node:
# | 2 | 6 | 8 |
# | 4 | 3 | 5 |
# | 7 | 1 | * |
#
# Iteration 263:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 715
# Current node:
# | 1 | 8 | 4 |
# | 2 | 6 | * |
# | 7 | 5 | 3 |
#
# Iteration 264:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 718
# Current node:
# | 1 | 6 | 8 |
# | 2 | 5 | * |
# | 7 | 3 | 4 |
#
# Iteration 265:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 721
# Current node:
# | 4 | * | 6 |
# | 1 | 2 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 266:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 724
# Current node:
# | 4 | * | 2 |
# | 8 | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 267:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 726
# Current node:
# | 2 | 1 | 6 |
# | 8 | 7 | 3 |
# | 4 | 5 | * |
#
# Iteration 268:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 728
# Current node:
# | 2 | 1 | 6 |
# | 8 | 3 | 5 |
# | 4 | 7 | * |
#
# Iteration 269:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 730
# Current node:
# | 4 | 2 | 8 |
# | 7 | 6 | 1 |
# | * | 5 | 3 |
#
# Iteration 270:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 732
# Current node:
# | 4 | 2 | 1 |
# | 7 | 5 | 6 |
# | * | 3 | 8 |
#
# Iteration 271:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 734
# Current node:
# | 4 | 2 | 6 |
# | 7 | 1 | 5 |
# | * | 3 | 8 |
#
# Iteration 272:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 736
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | * | 7 | 5 |
#
# Iteration 273:
# f(n) = 15, g(n) = 10, h(n) = 5
# Cumulative search cost = 738
# Current node:
# | 4 | 2 | 1 |
# | 8 | 6 | 3 |
# | * | 7 | 5 |
#
# Iteration 274:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 741
# Current node:
# | 8 | 2 | 6 |
# | * | 1 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 275:
# f(n) = 15, g(n) = 10, h(n) = 5
# Cumulative search cost = 743
# Current node:
# | 1 | 6 | 3 |
# | 2 | 4 | 5 |
# | 7 | 8 | * |
#
# Iteration 276:
# f(n) = 15, g(n) = 11, h(n) = 4
# Cumulative search cost = 746
# Current node:
# | 4 | * | 1 |
# | 8 | 2 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 277:
# f(n) = 15, g(n) = 11, h(n) = 4
# Cumulative search cost = 749
# Current node:
# | 4 | 2 | 1 |
# | * | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 278:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 752
# Current node:
# | 2 | 6 | 8 |
# | * | 5 | 1 |
# | 4 | 7 | 3 |
#
# Iteration 279:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 755
# Current node:
# | 2 | 6 | 8 |
# | 7 | 4 | 1 |
# | 5 | * | 3 |
#
# Iteration 280:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 758
# Current node:
# | 2 | 1 | 6 |
# | * | 3 | 5 |
# | 4 | 7 | 8 |
#
# Iteration 281:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 761
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 5 |
# | 3 | * | 8 |
#
# Iteration 282:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 764
# Current node:
# | 2 | 8 | 1 |
# | * | 5 | 6 |
# | 4 | 7 | 3 |
#
# Iteration 283:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 767
# Current node:
# | 2 | 8 | 1 |
# | 7 | 4 | 6 |
# | 5 | * | 3 |
#
# Iteration 284:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 771
# Current node:
# | 4 | 8 | 2 |
# | 1 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 285:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 773
# Current node:
# | * | 4 | 2 |
# | 1 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 286:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 776
# Current node:
# | 2 | 1 | 8 |
# | * | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 287:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 779
# Current node:
# | 1 | 6 | 8 |
# | * | 5 | 4 |
# | 2 | 7 | 3 |
#
# Iteration 288:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 782
# Current node:
# | 6 | * | 8 |
# | 1 | 2 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 289:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 785
# Current node:
# | 1 | 6 | 8 |
# | 7 | 2 | 4 |
# | 5 | * | 3 |
#
# Iteration 290:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 788
# Current node:
# | 4 | 2 | 6 |
# | 7 | 1 | 3 |
# | 8 | * | 5 |
#
# Iteration 291:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 791
# Current node:
# | 4 | 2 | 6 |
# | * | 8 | 3 |
# | 1 | 7 | 5 |
#
# Iteration 292:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 794
# Current node:
# | 1 | 4 | 6 |
# | * | 8 | 3 |
# | 2 | 7 | 5 |
#
# Iteration 293:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 797
# Current node:
# | 1 | 6 | 8 |
# | * | 4 | 3 |
# | 2 | 7 | 5 |
#
# Iteration 294:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 800
# Current node:
# | 2 | 6 | 3 |
# | 4 | 1 | 5 |
# | 7 | * | 8 |
#
# Iteration 295:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 802
# Current node:
# | * | 2 | 6 |
# | 4 | 5 | 8 |
# | 1 | 7 | 3 |
#
# Iteration 296:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 806
# Current node:
# | 4 | 2 | 6 |
# | 5 | * | 8 |
# | 1 | 7 | 3 |
#
# Iteration 297:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 810
# Current node:
# | 1 | 4 | 6 |
# | 5 | * | 8 |
# | 2 | 7 | 3 |
#
# Iteration 298:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 814
# Current node:
# | 1 | 4 | 6 |
# | 7 | * | 8 |
# | 5 | 2 | 3 |
#
# Iteration 299:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 816
# Current node:
# | 1 | 4 | 6 |
# | 7 | 2 | 8 |
# | 5 | 3 | * |
#
# Iteration 300:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 820
# Current node:
# | 2 | 1 | 6 |
# | 7 | * | 3 |
# | 8 | 4 | 5 |
#
# Iteration 301:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 824
# Current node:
# | 4 | 2 | 1 |
# | 7 | * | 6 |
# | 5 | 8 | 3 |
#
# Iteration 302:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 826
# Current node:
# | 4 | 2 | 1 |
# | 7 | 8 | 6 |
# | 5 | 3 | * |
#
# Iteration 303:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 828
# Current node:
# | * | 6 | 8 |
# | 2 | 1 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 304:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 832
# Current node:
# | 2 | 6 | 8 |
# | 1 | * | 3 |
# | 4 | 7 | 5 |
#
# Iteration 305:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 835
# Current node:
# | 4 | 1 | 6 |
# | 8 | 2 | * |
# | 7 | 5 | 3 |
#
# Iteration 306:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 837
# Current node:
# | 4 | 6 | 8 |
# | 1 | 2 | 3 |
# | 7 | 5 | * |
#
# Iteration 307:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 841
# Current node:
# | 4 | 6 | 8 |
# | 1 | * | 2 |
# | 7 | 5 | 3 |
#
# Iteration 308:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 843
# Current node:
# | * | 2 | 6 |
# | 4 | 7 | 8 |
# | 5 | 1 | 3 |
#
# Iteration 309:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 845
# Current node:
# | 4 | 2 | 6 |
# | 5 | 7 | 8 |
# | * | 1 | 3 |
#
# Iteration 310:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 847
# Current node:
# | 4 | 2 | * |
# | 7 | 8 | 6 |
# | 5 | 1 | 3 |
#
# Iteration 311:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 849
# Current node:
# | 4 | 2 | 6 |
# | 7 | 8 | 3 |
# | 5 | 1 | * |
#
# Iteration 312:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 851
# Current node:
# | 4 | 2 | * |
# | 7 | 1 | 6 |
# | 5 | 3 | 8 |
#
# Iteration 313:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 855
# Current node:
# | 4 | 2 | 6 |
# | 7 | * | 1 |
# | 5 | 3 | 8 |
#
# Iteration 314:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 858
# Current node:
# | 2 | 6 | 8 |
# | 5 | 1 | * |
# | 4 | 7 | 3 |
#
# Iteration 315:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 861
# Current node:
# | 2 | 1 | 6 |
# | 5 | 7 | * |
# | 4 | 3 | 8 |
#
# Iteration 316:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 864
# Current node:
# | 2 | * | 1 |
# | 5 | 8 | 6 |
# | 4 | 7 | 3 |
#
# Iteration 317:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 867
# Current node:
# | 2 | 1 | 6 |
# | 5 | 8 | 3 |
# | 4 | * | 7 |
#
# Iteration 318:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 870
# Current node:
# | 2 | 6 | 8 |
# | 7 | 1 | * |
# | 5 | 4 | 3 |
#
# Iteration 319:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 873
# Current node:
# | 2 | * | 1 |
# | 7 | 8 | 6 |
# | 5 | 4 | 3 |
#
# Iteration 320:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 876
# Current node:
# | 2 | 1 | 6 |
# | 7 | 8 | 3 |
# | 5 | * | 4 |
#
# Iteration 321:
# f(n) = 15, g(n) = 7, h(n) = 8
# Cumulative search cost = 879
# Current node:
# | 2 | * | 1 |
# | 7 | 4 | 6 |
# | 5 | 3 | 8 |
#
# Iteration 322:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 881
# Current node:
# | 2 | 6 | * |
# | 4 | 5 | 8 |
# | 7 | 3 | 1 |
#
# Iteration 323:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 885
# Current node:
# | 2 | 6 | 8 |
# | 4 | * | 5 |
# | 7 | 3 | 1 |
#
# Iteration 324:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 889
# Current node:
# | 6 | 4 | 8 |
# | 2 | * | 1 |
# | 7 | 5 | 3 |
#
# Iteration 325:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 891
# Current node:
# | 6 | 8 | * |
# | 2 | 4 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 326:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 893
# Current node:
# | 2 | 5 | 1 |
# | 4 | 3 | 6 |
# | 7 | 8 | * |
#
# Iteration 327:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 895
# Current node:
# | * | 5 | 1 |
# | 2 | 4 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 328:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 897
# Current node:
# | 2 | 5 | * |
# | 4 | 6 | 1 |
# | 7 | 3 | 8 |
#
# Iteration 329:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 899
# Current node:
# | 2 | 5 | 1 |
# | 4 | 6 | 8 |
# | 7 | 3 | * |
#
# Iteration 330:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 901
# Current node:
# | 2 | 6 | 5 |
# | 4 | 1 | 8 |
# | 7 | 3 | * |
#
# Iteration 331:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 905
# Current node:
# | 2 | 6 | 5 |
# | 4 | * | 1 |
# | 7 | 3 | 8 |
#
# Iteration 332:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 907
# Current node:
# | 2 | 8 | * |
# | 4 | 5 | 1 |
# | 7 | 3 | 6 |
#
# Iteration 333:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 911
# Current node:
# | 2 | 8 | 1 |
# | 4 | * | 5 |
# | 7 | 3 | 6 |
#
# Iteration 334:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 915
# Current node:
# | 8 | 4 | 1 |
# | 2 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 335:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 917
# Current node:
# | 8 | 1 | * |
# | 2 | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 336:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 920
# Current node:
# | 4 | 2 | 6 |
# | 1 | 3 | 5 |
# | 7 | * | 8 |
#
# Iteration 337:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 923
# Current node:
# | 1 | * | 4 |
# | 2 | 5 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 338:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 926
# Current node:
# | 1 | 4 | 6 |
# | 2 | 3 | 5 |
# | 7 | * | 8 |
#
# Iteration 339:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 929
# Current node:
# | 1 | 4 | 6 |
# | * | 2 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 340:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 932
# Current node:
# | 1 | 8 | 4 |
# | 2 | 5 | 6 |
# | 7 | * | 3 |
#
# Iteration 341:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 935
# Current node:
# | 1 | 8 | 4 |
# | * | 2 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 342:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 938
# Current node:
# | 2 | 3 | 1 |
# | 4 | 8 | 6 |
# | 7 | * | 5 |
#
# Iteration 343:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 941
# Current node:
# | 2 | 3 | 1 |
# | * | 4 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 344:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 944
# Current node:
# | 2 | 3 | 1 |
# | 4 | 6 | * |
# | 7 | 8 | 5 |
#
# Iteration 345:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 947
# Current node:
# | 6 | * | 8 |
# | 2 | 4 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 346:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 950
# Current node:
# | 2 | * | 6 |
# | 4 | 3 | 8 |
# | 7 | 1 | 5 |
#
# Iteration 347:
# f(n) = 15, g(n) = 10, h(n) = 5
# Cumulative search cost = 952
# Current node:
# | 4 | 2 | * |
# | 1 | 3 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 348:
# f(n) = 15, g(n) = 10, h(n) = 5
# Cumulative search cost = 954
# Current node:
# | 4 | 2 | * |
# | 8 | 5 | 1 |
# | 7 | 3 | 6 |
#
# Iteration 349:
# f(n) = 15, g(n) = 10, h(n) = 5
# Cumulative search cost = 958
# Current node:
# | 4 | 2 | 1 |
# | 8 | * | 5 |
# | 7 | 3 | 6 |
#
# Iteration 350:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 961
# Current node:
# | 2 | * | 1 |
# | 8 | 3 | 6 |
# | 4 | 7 | 5 |
#
# Iteration 351:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 963
# Current node:
# | 1 | 5 | 6 |
# | 2 | 7 | 8 |
# | * | 4 | 3 |
#
# Iteration 352:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 965
# Current node:
# | 1 | 5 | 6 |
# | 2 | 7 | 8 |
# | 4 | 3 | * |
#
# Iteration 353:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 967
# Current node:
# | 1 | 5 | 6 |
# | 4 | 2 | 8 |
# | * | 7 | 3 |
#
# Iteration 354:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 969
# Current node:
# | 1 | 5 | * |
# | 2 | 8 | 6 |
# | 4 | 7 | 3 |
#
# Iteration 355:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 971
# Current node:
# | 1 | 5 | 6 |
# | 2 | 8 | 3 |
# | 4 | 7 | * |
#
# Iteration 356:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 973
# Current node:
# | 1 | 6 | 8 |
# | 2 | 5 | 3 |
# | 4 | 7 | * |
#
# Iteration 357:
# f(n) = 15, g(n) = 8, h(n) = 7
# Cumulative search cost = 977
# Current node:
# | 1 | 6 | 8 |
# | 2 | * | 5 |
# | 4 | 7 | 3 |
#
# Iteration 358:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 980
# Current node:
# | 4 | 2 | 8 |
# | 6 | 5 | 1 |
# | 7 | * | 3 |
#
# Iteration 359:
# f(n) = 15, g(n) = 9, h(n) = 6
# Cumulative search cost = 983
# Current node:
# | 4 | 2 | 8 |
# | 6 | 1 | * |
# | 7 | 5 | 3 |
#
# Iteration 360:
# ...
# Current node:
# | * | 2 | 6 |
# | 4 | 8 | 3 |
# | 7 | 5 | 1 |
#
# Iteration 1632:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4455
# Current node:
# | * | 2 | 6 |
# | 4 | 3 | 1 |
# | 7 | 5 | 8 |
#
# Iteration 1633:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4459
# Current node:
# | 4 | 2 | 6 |
# | 3 | * | 1 |
# | 7 | 5 | 8 |
#
# Iteration 1634:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4462
# Current node:
# | 5 | 2 | 1 |
# | * | 7 | 6 |
# | 4 | 3 | 8 |
#
# Iteration 1635:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4465
# Current node:
# | 5 | 2 | 6 |
# | * | 1 | 7 |
# | 4 | 3 | 8 |
#
# Iteration 1636:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4468
# Current node:
# | 5 | 2 | 6 |
# | * | 1 | 3 |
# | 4 | 8 | 7 |
#
# Iteration 1637:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4471
# Current node:
# | 2 | * | 6 |
# | 8 | 1 | 3 |
# | 5 | 4 | 7 |
#
# Iteration 1638:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4474
# Current node:
# | 2 | 1 | 6 |
# | 8 | 4 | 3 |
# | 5 | * | 7 |
#
# Iteration 1639:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4477
# Current node:
# | 2 | 1 | 6 |
# | 8 | 3 | * |
# | 5 | 4 | 7 |
#
# Iteration 1640:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4480
# Current node:
# | 7 | 2 | 6 |
# | * | 1 | 3 |
# | 5 | 8 | 4 |
#
# Iteration 1641:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4484
# Current node:
# | 6 | 8 | 1 |
# | 2 | * | 3 |
# | 7 | 4 | 5 |
#
# Iteration 1642:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4488
# Current node:
# | 8 | 1 | 6 |
# | 2 | * | 3 |
# | 7 | 4 | 5 |
#
# Iteration 1643:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4491
# Current node:
# | 1 | * | 8 |
# | 2 | 5 | 4 |
# | 7 | 3 | 6 |
#
# Iteration 1644:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4493
# Current node:
# | 1 | 6 | * |
# | 2 | 7 | 8 |
# | 4 | 3 | 5 |
#
# Iteration 1645:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4497
# Current node:
# | 1 | 6 | 8 |
# | 2 | * | 7 |
# | 4 | 3 | 5 |
#
# Iteration 1646:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4501
# Current node:
# | 1 | 6 | 8 |
# | 4 | * | 5 |
# | 7 | 2 | 3 |
#
# Iteration 1647:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4503
# Current node:
# | 1 | 6 | 8 |
# | 4 | 2 | 5 |
# | 7 | 3 | * |
#
# Iteration 1648:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4506
# Current node:
# | 4 | 2 | 1 |
# | * | 5 | 8 |
# | 7 | 6 | 3 |
#
# Iteration 1649:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4509
# Current node:
# | 4 | 2 | 1 |
# | 5 | 8 | * |
# | 7 | 6 | 3 |
#
# Iteration 1650:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4513
# Current node:
# | 1 | 6 | 3 |
# | 4 | * | 8 |
# | 7 | 2 | 5 |
#
# Iteration 1651:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4517
# Current node:
# | 5 | 2 | 1 |
# | 4 | * | 6 |
# | 7 | 8 | 3 |
#
# Iteration 1652:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4519
# Current node:
# | 5 | 2 | 1 |
# | 4 | 8 | 6 |
# | 7 | 3 | * |
#
# Iteration 1653:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4522
# Current node:
# | 3 | 2 | 6 |
# | * | 1 | 4 |
# | 7 | 5 | 8 |
#
# Iteration 1654:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4525
# Current node:
# | 4 | 2 | 3 |
# | * | 1 | 8 |
# | 7 | 6 | 5 |
#
# Iteration 1655:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4528
# Current node:
# | 2 | * | 1 |
# | 8 | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 1656:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4531
# Current node:
# | 7 | 2 | 6 |
# | 8 | 1 | 3 |
# | 4 | * | 5 |
#
# Iteration 1657:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4535
# Current node:
# | 1 | 8 | 6 |
# | 2 | * | 3 |
# | 7 | 5 | 4 |
#
# Iteration 1658:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4537
# Current node:
# | 1 | 6 | * |
# | 2 | 8 | 3 |
# | 7 | 5 | 4 |
#
# Iteration 1659:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4540
# Current node:
# | 4 | 2 | 3 |
# | 8 | 1 | 6 |
# | 7 | * | 5 |
#
# Iteration 1660:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4543
# Current node:
# | 4 | 2 | 3 |
# | 8 | 6 | * |
# | 7 | 1 | 5 |
#
# Iteration 1661:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4546
# Current node:
# | 1 | 2 | 6 |
# | 8 | 5 | 4 |
# | 7 | * | 3 |
#
# Iteration 1662:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4549
# Current node:
# | 1 | * | 8 |
# | 2 | 3 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 1663:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4552
# Current node:
# | 7 | 2 | 6 |
# | * | 1 | 4 |
# | 3 | 8 | 5 |
#
# Iteration 1664:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4555
# Current node:
# | 4 | * | 2 |
# | 1 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 1665:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4558
# Current node:
# | 4 | 8 | 2 |
# | * | 1 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 1666:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4561
# Current node:
# | 4 | 8 | 2 |
# | 1 | 3 | * |
# | 7 | 6 | 5 |
#
# Iteration 1667:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4564
# Current node:
# | 4 | 2 | 6 |
# | 8 | 5 | 3 |
# | 7 | * | 1 |
#
# Iteration 1668:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4567
# Current node:
# | 4 | 2 | 6 |
# | 8 | 3 | * |
# | 7 | 5 | 1 |
#
# Iteration 1669:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4570
# Current node:
# | 8 | * | 3 |
# | 2 | 1 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 1670:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4573
# Current node:
# | 8 | 1 | 3 |
# | * | 2 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 1671:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4576
# Current node:
# | 1 | * | 2 |
# | 8 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 1672:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4579
# Current node:
# | 1 | 4 | 2 |
# | 8 | 3 | * |
# | 7 | 6 | 5 |
#
# Iteration 1673:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4581
# Current node:
# | 1 | 6 | * |
# | 8 | 2 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 1674:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4584
# Current node:
# | 1 | 2 | 8 |
# | * | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 1675:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4587
# Current node:
# | 1 | 2 | 8 |
# | 4 | 3 | * |
# | 7 | 6 | 5 |
#
# Iteration 1676:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4591
# Current node:
# | 2 | 1 | 6 |
# | 8 | * | 4 |
# | 7 | 3 | 5 |
#
# Iteration 1677:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4595
# Current node:
# | 2 | 1 | 8 |
# | 7 | * | 4 |
# | 5 | 6 | 3 |
#
# Iteration 1678:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4599
# Current node:
# | 8 | 2 | 4 |
# | 1 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 1679:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4603
# Current node:
# | 2 | 3 | 1 |
# | 4 | * | 5 |
# | 7 | 6 | 8 |
#
# Iteration 1680:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4606
# Current node:
# | 1 | 4 | 2 |
# | * | 3 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 1681:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4609
# Current node:
# | 4 | 8 | 3 |
# | 6 | 2 | * |
# | 7 | 1 | 5 |
#
# Iteration 1682:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4613
# Current node:
# | 4 | 2 | 3 |
# | 7 | * | 1 |
# | 8 | 6 | 5 |
#
# Iteration 1683:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4616
# Current node:
# | 4 | 6 | 3 |
# | 8 | 2 | * |
# | 1 | 7 | 5 |
#
# Iteration 1684:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4619
# Current node:
# | 8 | 2 | 1 |
# | 4 | 3 | 6 |
# | 7 | * | 5 |
#
# Iteration 1685:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4623
# Current node:
# | 1 | 8 | 3 |
# | 2 | * | 5 |
# | 7 | 6 | 4 |
#
# Iteration 1686:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4626
# Current node:
# | 6 | 8 | 3 |
# | 1 | 2 | * |
# | 7 | 4 | 5 |
#
# Iteration 1687:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4628
# Current node:
# | * | 2 | 8 |
# | 7 | 6 | 3 |
# | 1 | 4 | 5 |
#
# Iteration 1688:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4631
# Current node:
# | 4 | 6 | 2 |
# | 8 | 1 | 3 |
# | 7 | * | 5 |
#
# Iteration 1689:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4633
# Current node:
# | * | 2 | 1 |
# | 8 | 7 | 6 |
# | 4 | 5 | 3 |
#
# Iteration 1690:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4635
# Current node:
# | * | 2 | 6 |
# | 8 | 1 | 7 |
# | 4 | 5 | 3 |
#
# Iteration 1691:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4637
# Current node:
# | * | 2 | 6 |
# | 8 | 1 | 5 |
# | 4 | 3 | 7 |
#
# Iteration 1692:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4639
# Current node:
# | * | 2 | 1 |
# | 6 | 8 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 1693:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4642
# Current node:
# | 2 | 1 | 6 |
# | 3 | 7 | * |
# | 4 | 8 | 5 |
#
# Iteration 1694:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4645
# Current node:
# | 1 | * | 6 |
# | 2 | 7 | 5 |
# | 3 | 4 | 8 |
#
# Iteration 1695:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4647
# Current node:
# | 8 | 2 | * |
# | 4 | 1 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 1696:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4650
# Current node:
# | 1 | 8 | 3 |
# | 4 | 6 | * |
# | 2 | 7 | 5 |
#
# Iteration 1697:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4654
# Current node:
# | 1 | 2 | 4 |
# | 7 | * | 6 |
# | 5 | 3 | 8 |
#
# Iteration 1698:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4656
# Current node:
# | * | 2 | 1 |
# | 7 | 3 | 6 |
# | 8 | 4 | 5 |
#
# Iteration 1699:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4660
# Current node:
# | 4 | 2 | 1 |
# | 7 | * | 3 |
# | 5 | 6 | 8 |
#
# Iteration 1700:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4662
# Current node:
# | 4 | 2 | 1 |
# | 7 | 3 | 8 |
# | 5 | 6 | * |
#
# Iteration 1701:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4664
# Current node:
# | * | 2 | 6 |
# | 1 | 3 | 8 |
# | 4 | 7 | 5 |
#
# Iteration 1702:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4667
# Current node:
# | 2 | 6 | 3 |
# | 5 | 1 | * |
# | 4 | 8 | 7 |
#
# Iteration 1703:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4670
# Current node:
# | 1 | * | 6 |
# | 2 | 8 | 3 |
# | 5 | 4 | 7 |
#
# Iteration 1704:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4673
# Current node:
# | 2 | 6 | 8 |
# | * | 1 | 3 |
# | 7 | 5 | 4 |
#
# Iteration 1705:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4676
# Current node:
# | 2 | 6 | 3 |
# | 7 | 1 | * |
# | 5 | 8 | 4 |
#
# Iteration 1706:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4679
# Current node:
# | 1 | * | 6 |
# | 2 | 7 | 3 |
# | 5 | 8 | 4 |
#
# Iteration 1707:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 4682
# Current node:
# | 2 | 4 | 1 |
# | * | 3 | 6 |
# | 7 | 5 | 8 |
#
# Iteration 1708:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4684
# Current node:
# | * | 2 | 5 |
# | 4 | 3 | 1 |
# | 7 | 8 | 6 |
#
# Iteration 1709:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4686
# Current node:
# | * | 2 | 1 |
# | 4 | 5 | 3 |
# | 7 | 8 | 6 |
#
# Iteration 1710:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4690
# Current node:
# | 5 | 1 | 6 |
# | 2 | * | 4 |
# | 7 | 3 | 8 |
#
# Iteration 1711:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4692
# Current node:
# | * | 2 | 5 |
# | 4 | 6 | 8 |
# | 7 | 1 | 3 |
#
# Iteration 1712:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4694
# Current node:
# | 2 | 5 | 8 |
# | 4 | 3 | 1 |
# | 7 | 6 | * |
#
# Iteration 1713:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4698
# Current node:
# | 1 | 5 | 6 |
# | 8 | * | 3 |
# | 2 | 4 | 7 |
#
# Iteration 1714:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4700
# Current node:
# | * | 2 | 6 |
# | 5 | 1 | 4 |
# | 3 | 7 | 8 |
#
# Iteration 1715:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4703
# Current node:
# | 1 | 4 | 8 |
# | * | 6 | 3 |
# | 7 | 2 | 5 |
#
# Iteration 1716:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4706
# Current node:
# | 4 | 8 | 3 |
# | 1 | 6 | * |
# | 7 | 2 | 5 |
#
# Iteration 1717:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4709
# Current node:
# | 1 | * | 3 |
# | 2 | 4 | 8 |
# | 7 | 6 | 5 |
#
# Iteration 1718:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4712
# Current node:
# | 2 | 1 | 4 |
# | 8 | 6 | 3 |
# | 7 | * | 5 |
#
# Iteration 1719:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4714
# Current node:
# | * | 2 | 6 |
# | 8 | 4 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 1720:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4716
# Current node:
# | * | 2 | 1 |
# | 7 | 4 | 6 |
# | 3 | 8 | 5 |
#
# Iteration 1721:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4719
# Current node:
# | 1 | 2 | 6 |
# | 8 | 4 | 3 |
# | 7 | * | 5 |
#
# Iteration 1722:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4722
# Current node:
# | 1 | 4 | 3 |
# | 2 | 8 | * |
# | 7 | 6 | 5 |
#
# Iteration 1723:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4725
# Current node:
# | 2 | 1 | 6 |
# | * | 8 | 4 |
# | 7 | 3 | 5 |
#
# Iteration 1724:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4728
# Current node:
# | 1 | * | 6 |
# | 2 | 7 | 4 |
# | 3 | 8 | 5 |
#
# Iteration 1725:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4731
# Current node:
# | 2 | 6 | 3 |
# | 8 | 1 | * |
# | 7 | 5 | 4 |
#
# Iteration 1726:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4733
# Current node:
# | * | 2 | 6 |
# | 7 | 1 | 4 |
# | 8 | 5 | 3 |
#
# Iteration 1727:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4735
# Current node:
# | 2 | 1 | 6 |
# | 8 | 7 | 4 |
# | * | 5 | 3 |
#
# Iteration 1728:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4738
# Current node:
# | 1 | 6 | 3 |
# | 2 | 7 | * |
# | 8 | 4 | 5 |
#
# Iteration 1729:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4740
# Current node:
# | * | 2 | 3 |
# | 4 | 8 | 5 |
# | 7 | 6 | 1 |
#
# Iteration 1730:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4742
# Current node:
# | * | 2 | 8 |
# | 7 | 6 | 4 |
# | 5 | 3 | 1 |
#
# Iteration 1731:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4744
# Current node:
# | * | 2 | 1 |
# | 7 | 8 | 4 |
# | 5 | 3 | 6 |
#
# Iteration 1732:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4746
# Current node:
# | 2 | 8 | 1 |
# | 7 | 3 | 4 |
# | 5 | 6 | * |
#
# Iteration 1733:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4748
# Current node:
# | * | 2 | 6 |
# | 8 | 1 | 3 |
# | 5 | 4 | 7 |
#
# Iteration 1734:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4751
# Current node:
# | 1 | 6 | 8 |
# | 4 | 2 | * |
# | 7 | 3 | 5 |
#
# Iteration 1735:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4753
# Current node:
# | * | 2 | 1 |
# | 8 | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 1736:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4755
# Current node:
# | 4 | 2 | * |
# | 1 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 1737:
# f(n) = 18, g(n) = 16, h(n) = 2
# Cumulative search cost = 4757
# Current node:
# | * | 1 | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 1738:
# f(n) = 18, g(n) = 16, h(n) = 2
# Cumulative search cost = 4759
# Current node:
# | 1 | 2 | * |
# | 8 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 1739:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 4762
# Current node:
# | 1 | 2 | 6 |
# | * | 3 | 8 |
# | 4 | 7 | 5 |
#
# Iteration 1740:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 4764
# Current node:
# | 2 | 6 | 3 |
# | 7 | 1 | 4 |
# | 5 | 8 | * |
#
# Iteration 1741:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4768
# Current node:
# | 2 | 1 | 4 |
# | 8 | * | 3 |
# | 7 | 6 | 5 |
#
# Iteration 1742:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 4770
# Current node:
# | 2 | 6 | 3 |
# | 8 | 1 | 4 |
# | 7 | 5 | * |
#
# Iteration 1743:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4773
# Current node:
# | 4 | 2 | 3 |
# | 1 | 8 | * |
# | 7 | 6 | 5 |
#
# Iteration 1744:
# f(n) = 18, g(n) = 17, h(n) = 1
# Cumulative search cost = 4776
# Current node:
# | 1 | * | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 1745:
# f(n) = 18, g(n) = 17, h(n) = 1
# Cumulative search cost = 4779
# Current node:
# | 1 | 2 | 3 |
# | 8 | 4 | * |
# | 7 | 6 | 5 |
#
# Iteration 1746:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 4782
# Current node:
# | 2 | 6 | 3 |
# | 8 | 1 | 4 |
# | 7 | * | 5 |
#
# Goal node found!
# Solution found for 1746 iterations of A* search. The heuristic function is the number of misplaced tiles.
# Search cost: 4782 nodes generated

# %%
solution_astar_misplaced = get_solution(result_misplaced)
i = 1
for node in solution_astar_misplaced:
    print(f"Step {i}: f(n) = {node.f}, g(n) = {node.g}, h(n) = {node.h} \n{node.puzzle}")
    i += 1
# Out:
# Step 1: f(n) = 7, g(n) = 0, h(n) = 7
# | 2 | 1 | 6 |
# | 4 | * | 8 |
# | 7 | 5 | 3 |
#
# Step 2: f(n) = 8, g(n) = 1, h(n) = 7
# | 2 | 1 | 6 |
# | 4 | 8 | * |
# | 7 | 5 | 3 |
#
# Step 3: f(n) = 9, g(n) = 2, h(n) = 7
# | 2 | 1 | * |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Step 4: f(n) = 10, g(n) = 3, h(n) = 7
# | 2 | * | 1 |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Step 5: f(n) = 11, g(n) = 4, h(n) = 7
# | 2 | 8 | 1 |
# | 4 | * | 6 |
# | 7 | 5 | 3 |
#
# Step 6: f(n) = 12, g(n) = 5, h(n) = 7
# | 2 | 8 | 1 |
# | 4 | 6 | * |
# | 7 | 5 | 3 |
#
# Step 7: f(n) = 13, g(n) = 6, h(n) = 7
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | 5 | * |
#
# Step 8: f(n) = 13, g(n) = 7, h(n) = 6
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | * | 5 |
#
# Step 9: f(n) = 13, g(n) = 8, h(n) = 5
# | 2 | 8 | 1 |
# | 4 | * | 3 |
# | 7 | 6 | 5 |
#
# Step 10: f(n) = 14, g(n) = 9, h(n) = 5
# | 2 | 8 | 1 |
# | * | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 11: f(n) = 15, g(n) = 10, h(n) = 5
# | * | 8 | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 12: f(n) = 16, g(n) = 11, h(n) = 5
# | 8 | * | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 13: f(n) = 17, g(n) = 12, h(n) = 5
# | 8 | 1 | * |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 14: f(n) = 17, g(n) = 13, h(n) = 4
# | 8 | 1 | 3 |
# | 2 | 4 | * |
# | 7 | 6 | 5 |
#
# Step 15: f(n) = 17, g(n) = 14, h(n) = 3
# | 8 | 1 | 3 |
# | 2 | * | 4 |
# | 7 | 6 | 5 |
#
# Step 16: f(n) = 18, g(n) = 15, h(n) = 3
# | 8 | 1 | 3 |
# | * | 2 | 4 |
# | 7 | 6 | 5 |
#
# Step 17: f(n) = 18, g(n) = 16, h(n) = 2
# | * | 1 | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Step 18: f(n) = 18, g(n) = 17, h(n) = 1
# | 1 | * | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Step 19: f(n) = 18, g(n) = 18, h(n) = 0
# | 1 | 2 | 3 |
# | 8 | * | 4 |
# | 7 | 6 | 5 |

# %% [markdown]
# ### A* Search using Manhattan Distance as the Heuristic

# %%
iters_manhattan, search_cost_manhattan, result_manhattan = astar_search(start_puzzle, goal_puzzle, "manhattan")
print(f"Solution found for {iters_manhattan} iterations of A* search. The heuristic function is Manhattan Distance.")
print(f"Search cost: {search_cost_manhattan} nodes generated")
# Out:
# Iteration 1:
# f(n) = 12, g(n) = 0, h(n) = 12
# Cumulative search cost = 4
# Current node:
# | 2 | 1 | 6 |
# | 4 | * | 8 |
# | 7 | 5 | 3 |
#
# Iteration 2:
# f(n) = 12, g(n) = 1, h(n) = 11
# Cumulative search cost = 7
# Current node:
# | 2 | 1 | 6 |
# | * | 4 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 3:
# f(n) = 12, g(n) = 1, h(n) = 11
# Cumulative search cost = 10
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | * |
# | 7 | 5 | 3 |
#
# Iteration 4:
# f(n) = 12, g(n) = 2, h(n) = 10
# Cumulative search cost = 12
# Current node:
# | 2 | 1 | * |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 5:
# f(n) = 12, g(n) = 2, h(n) = 10
# Cumulative search cost = 14
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | 3 |
# | 7 | 5 | * |
#
# Iteration 6:
# f(n) = 12, g(n) = 3, h(n) = 9
# Cumulative search cost = 17
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | 3 |
# | 7 | * | 5 |
#
# Iteration 7:
# f(n) = 14, g(n) = 1, h(n) = 13
# Cumulative search cost = 20
# Current node:
# | 2 | * | 6 |
# | 4 | 1 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 8:
# f(n) = 14, g(n) = 1, h(n) = 13
# Cumulative search cost = 23
# Current node:
# | 2 | 1 | 6 |
# | 4 | 5 | 8 |
# | 7 | * | 3 |
#
# Iteration 9:
# f(n) = 14, g(n) = 2, h(n) = 12
# Cumulative search cost = 25
# Current node:
# | * | 1 | 6 |
# | 2 | 4 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 10:
# f(n) = 14, g(n) = 2, h(n) = 12
# Cumulative search cost = 27
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 8 |
# | * | 5 | 3 |
#
# Iteration 11:
# f(n) = 14, g(n) = 3, h(n) = 11
# Cumulative search cost = 30
# Current node:
# | 2 | * | 1 |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 12:
# f(n) = 14, g(n) = 4, h(n) = 10
# Cumulative search cost = 34
# Current node:
# | 2 | 1 | 6 |
# | 4 | * | 3 |
# | 7 | 8 | 5 |
#
# Iteration 13:
# f(n) = 14, g(n) = 4, h(n) = 10
# Cumulative search cost = 36
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | 3 |
# | * | 7 | 5 |
#
# Iteration 14:
# f(n) = 14, g(n) = 2, h(n) = 12
# Cumulative search cost = 38
# Current node:
# | * | 2 | 6 |
# | 4 | 1 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 15:
# f(n) = 14, g(n) = 2, h(n) = 12
# Cumulative search cost = 40
# Current node:
# | 2 | 6 | * |
# | 4 | 1 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 16:
# f(n) = 14, g(n) = 3, h(n) = 11
# Cumulative search cost = 43
# Current node:
# | 1 | * | 6 |
# | 2 | 4 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 17:
# f(n) = 14, g(n) = 4, h(n) = 10
# Cumulative search cost = 45
# Current node:
# | * | 2 | 1 |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 18:
# f(n) = 14, g(n) = 5, h(n) = 9
# Cumulative search cost = 48
# Current node:
# | 2 | 1 | 6 |
# | * | 4 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 19:
# f(n) = 14, g(n) = 4, h(n) = 10
# Cumulative search cost = 50
# Current node:
# | 1 | 6 | * |
# | 2 | 4 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 20:
# f(n) = 16, g(n) = 2, h(n) = 14
# Cumulative search cost = 52
# Current node:
# | 2 | 1 | 6 |
# | 4 | 5 | 8 |
# | * | 7 | 3 |
#
# Iteration 21:
# f(n) = 16, g(n) = 2, h(n) = 14
# Cumulative search cost = 54
# Current node:
# | 2 | 1 | 6 |
# | 4 | 5 | 8 |
# | 7 | 3 | * |
#
# Iteration 22:
# f(n) = 16, g(n) = 3, h(n) = 13
# Cumulative search cost = 57
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 8 |
# | 5 | * | 3 |
#
# Iteration 23:
# f(n) = 16, g(n) = 4, h(n) = 12
# Cumulative search cost = 61
# Current node:
# | 2 | 8 | 1 |
# | 4 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 24:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 64
# Current node:
# | 2 | * | 6 |
# | 4 | 1 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 25:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 67
# Current node:
# | 2 | 1 | 6 |
# | 4 | 3 | * |
# | 7 | 8 | 5 |
#
# Iteration 26:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 70
# Current node:
# | 2 | 1 | 6 |
# | * | 8 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 27:
# f(n) = 16, g(n) = 3, h(n) = 13
# Cumulative search cost = 73
# Current node:
# | 4 | 2 | 6 |
# | * | 1 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 28:
# f(n) = 16, g(n) = 3, h(n) = 13
# Cumulative search cost = 76
# Current node:
# | 2 | 6 | 8 |
# | 4 | 1 | * |
# | 7 | 5 | 3 |
#
# Iteration 29:
# f(n) = 16, g(n) = 4, h(n) = 12
# Cumulative search cost = 80
# Current node:
# | 1 | 4 | 6 |
# | 2 | * | 8 |
# | 7 | 5 | 3 |
#
# Iteration 30:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 83
# Current node:
# | 4 | 2 | 1 |
# | * | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 31:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 85
# Current node:
# | * | 1 | 6 |
# | 2 | 4 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 32:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 87
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 3 |
# | * | 8 | 5 |
#
# Iteration 33:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 90
# Current node:
# | 1 | 6 | 8 |
# | 2 | 4 | * |
# | 7 | 5 | 3 |
#
# Iteration 34:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 93
# Current node:
# | 2 | 8 | 1 |
# | * | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 35:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 96
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | * |
# | 7 | 5 | 3 |
#
# Iteration 36:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 98
# Current node:
# | * | 2 | 6 |
# | 4 | 1 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 37:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 100
# Current node:
# | 2 | 6 | * |
# | 4 | 1 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 38:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 102
# Current node:
# | 2 | 1 | * |
# | 4 | 3 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 39:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 106
# Current node:
# | 2 | 1 | 6 |
# | 8 | * | 3 |
# | 4 | 7 | 5 |
#
# Iteration 40:
# f(n) = 16, g(n) = 4, h(n) = 12
# Cumulative search cost = 110
# Current node:
# | 4 | 2 | 6 |
# | 1 | * | 8 |
# | 7 | 5 | 3 |
#
# Iteration 41:
# f(n) = 16, g(n) = 4, h(n) = 12
# Cumulative search cost = 112
# Current node:
# | 2 | 6 | 8 |
# | 4 | 1 | 3 |
# | 7 | 5 | * |
#
# Iteration 42:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 115
# Current node:
# | 1 | 4 | 6 |
# | * | 2 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 43:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 118
# Current node:
# | 1 | 4 | 6 |
# | 2 | 8 | * |
# | 7 | 5 | 3 |
#
# Iteration 44:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 122
# Current node:
# | 4 | 2 | 1 |
# | 8 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 45:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 125
# Current node:
# | 1 | * | 6 |
# | 2 | 4 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 46:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 128
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 3 |
# | 8 | * | 5 |
#
# Iteration 47:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 130
# Current node:
# | 1 | 6 | 8 |
# | 2 | 4 | 3 |
# | 7 | 5 | * |
#
# Iteration 48:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 134
# Current node:
# | 1 | 6 | 8 |
# | 2 | * | 4 |
# | 7 | 5 | 3 |
#
# Iteration 49:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 136
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | 5 | * |
#
# Iteration 50:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 139
# Current node:
# | 2 | 6 | 3 |
# | 4 | 1 | * |
# | 7 | 8 | 5 |
#
# Iteration 51:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 142
# Current node:
# | 4 | 2 | 6 |
# | 1 | 8 | * |
# | 7 | 5 | 3 |
#
# Iteration 52:
# f(n) = 16, g(n) = 5, h(n) = 11
# Cumulative search cost = 145
# Current node:
# | 2 | 6 | 8 |
# | 4 | 1 | 3 |
# | 7 | * | 5 |
#
# Iteration 53:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 147
# Current node:
# | 1 | 4 | * |
# | 2 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 54:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 149
# Current node:
# | 1 | 4 | 6 |
# | 2 | 8 | 3 |
# | 7 | 5 | * |
#
# Iteration 55:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 152
# Current node:
# | 4 | 2 | 1 |
# | 8 | 6 | * |
# | 7 | 5 | 3 |
#
# Iteration 56:
# f(n) = 16, g(n) = 8, h(n) = 8
# Cumulative search cost = 154
# Current node:
# | 1 | 6 | * |
# | 2 | 4 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 57:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 157
# Current node:
# | 1 | 6 | 8 |
# | 2 | 4 | 3 |
# | 7 | * | 5 |
#
# Iteration 58:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 160
# Current node:
# | 1 | * | 8 |
# | 2 | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 59:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 163
# Current node:
# | 1 | 6 | 8 |
# | * | 2 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 60:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 166
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | * | 5 |
#
# Iteration 61:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 168
# Current node:
# | 4 | 2 | * |
# | 1 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 62:
# f(n) = 16, g(n) = 6, h(n) = 10
# Cumulative search cost = 170
# Current node:
# | 4 | 2 | 6 |
# | 1 | 8 | 3 |
# | 7 | 5 | * |
#
# Iteration 63:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 173
# Current node:
# | 1 | * | 4 |
# | 2 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 64:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 176
# Current node:
# | 1 | 4 | 6 |
# | 2 | 8 | 3 |
# | 7 | * | 5 |
#
# Iteration 65:
# f(n) = 16, g(n) = 8, h(n) = 8
# Cumulative search cost = 178
# Current node:
# | 4 | 2 | 1 |
# | 8 | 6 | 3 |
# | 7 | 5 | * |
#
# Iteration 66:
# f(n) = 16, g(n) = 9, h(n) = 7
# Cumulative search cost = 181
# Current node:
# | 1 | 6 | 3 |
# | 2 | 4 | * |
# | 7 | 8 | 5 |
#
# Iteration 67:
# f(n) = 16, g(n) = 8, h(n) = 8
# Cumulative search cost = 183
# Current node:
# | 1 | 8 | * |
# | 2 | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 68:
# f(n) = 16, g(n) = 8, h(n) = 8
# Cumulative search cost = 187
# Current node:
# | 2 | 8 | 1 |
# | 4 | * | 3 |
# | 7 | 6 | 5 |
#
# Iteration 69:
# f(n) = 16, g(n) = 7, h(n) = 9
# Cumulative search cost = 190
# Current node:
# | 4 | 2 | 6 |
# | 1 | 8 | 3 |
# | 7 | * | 5 |
#
# Iteration 70:
# f(n) = 16, g(n) = 9, h(n) = 7
# Cumulative search cost = 193
# Current node:
# | 4 | 2 | 1 |
# | 8 | 6 | 3 |
# | 7 | * | 5 |
#
# Iteration 71:
# f(n) = 16, g(n) = 10, h(n) = 6
# Cumulative search cost = 197
# Current node:
# | 1 | 6 | 3 |
# | 2 | * | 4 |
# | 7 | 8 | 5 |
#
# Iteration 72:
# f(n) = 16, g(n) = 9, h(n) = 7
# Cumulative search cost = 200
# Current node:
# | 2 | * | 1 |
# | 4 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 73:
# f(n) = 16, g(n) = 9, h(n) = 7
# Cumulative search cost = 203
# Current node:
# | 2 | 8 | 1 |
# | * | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 74:
# f(n) = 16, g(n) = 10, h(n) = 6
# Cumulative search cost = 207
# Current node:
# | 4 | 2 | 1 |
# | 8 | * | 3 |
# | 7 | 6 | 5 |
#
# Iteration 75:
# f(n) = 16, g(n) = 11, h(n) = 5
# Cumulative search cost = 210
# Current node:
# | 1 | * | 3 |
# | 2 | 6 | 4 |
# | 7 | 8 | 5 |
#
# Iteration 76:
# f(n) = 16, g(n) = 11, h(n) = 5
# Cumulative search cost = 213
# Current node:
# | 1 | 6 | 3 |
# | 2 | 8 | 4 |
# | 7 | * | 5 |
#
# Iteration 77:
# f(n) = 16, g(n) = 11, h(n) = 5
# Cumulative search cost = 216
# Current node:
# | 1 | 6 | 3 |
# | * | 2 | 4 |
# | 7 | 8 | 5 |
#
# Iteration 78:
# f(n) = 16, g(n) = 10, h(n) = 6
# Cumulative search cost = 218
# Current node:
# | * | 2 | 1 |
# | 4 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 79:
# f(n) = 16, g(n) = 10, h(n) = 6
# Cumulative search cost = 220
# Current node:
# | 2 | 1 | * |
# | 4 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 80:
# f(n) = 16, g(n) = 11, h(n) = 5
# Cumulative search cost = 223
# Current node:
# | 2 | 1 | 3 |
# | 4 | 8 | * |
# | 7 | 6 | 5 |
#
# Iteration 81:
# f(n) = 18, g(n) = 3, h(n) = 15
# Cumulative search cost = 226
# Current node:
# | 2 | 1 | 6 |
# | * | 5 | 8 |
# | 4 | 7 | 3 |
#
# Iteration 82:
# f(n) = 18, g(n) = 3, h(n) = 15
# Cumulative search cost = 229
# Current node:
# | 2 | 1 | 6 |
# | 4 | 5 | * |
# | 7 | 3 | 8 |
#
# Iteration 83:
# f(n) = 18, g(n) = 4, h(n) = 14
# Cumulative search cost = 233
# Current node:
# | 2 | 1 | 6 |
# | 7 | * | 8 |
# | 5 | 4 | 3 |
#
# Iteration 84:
# f(n) = 18, g(n) = 4, h(n) = 14
# Cumulative search cost = 235
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 8 |
# | 5 | 3 | * |
#
# Iteration 85:
# f(n) = 18, g(n) = 5, h(n) = 13
# Cumulative search cost = 238
# Current node:
# | 2 | 8 | 1 |
# | 4 | 5 | 6 |
# | 7 | * | 3 |
#
# Iteration 86:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 240
# Current node:
# | 2 | 1 | 6 |
# | 4 | 3 | 5 |
# | 7 | 8 | * |
#
# Iteration 87:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 242
# Current node:
# | * | 1 | 6 |
# | 2 | 8 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 88:
# f(n) = 18, g(n) = 4, h(n) = 14
# Cumulative search cost = 244
# Current node:
# | 4 | 2 | 6 |
# | 7 | 1 | 8 |
# | * | 5 | 3 |
#
# Iteration 89:
# f(n) = 18, g(n) = 4, h(n) = 14
# Cumulative search cost = 248
# Current node:
# | 2 | 6 | 8 |
# | 4 | * | 1 |
# | 7 | 5 | 3 |
#
# Iteration 90:
# f(n) = 18, g(n) = 5, h(n) = 13
# Cumulative search cost = 251
# Current node:
# | 1 | 4 | 6 |
# | 2 | 5 | 8 |
# | 7 | * | 3 |
#
# Iteration 91:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 253
# Current node:
# | 4 | 2 | 1 |
# | 7 | 8 | 6 |
# | * | 5 | 3 |
#
# Iteration 92:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 255
# Current node:
# | * | 8 | 1 |
# | 2 | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 93:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 257
# Current node:
# | 2 | 8 | 1 |
# | 7 | 4 | 6 |
# | * | 5 | 3 |
#
# Iteration 94:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 259
# Current node:
# | 2 | 8 | * |
# | 4 | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 95:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 262
# Current node:
# | 4 | 2 | 6 |
# | * | 1 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 96:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 265
# Current node:
# | 2 | * | 1 |
# | 4 | 3 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 97:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 268
# Current node:
# | 2 | * | 6 |
# | 8 | 1 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 98:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 271
# Current node:
# | 2 | 1 | 6 |
# | 8 | 7 | 3 |
# | 4 | * | 5 |
#
# Iteration 99:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 274
# Current node:
# | 2 | 1 | 6 |
# | 8 | 3 | * |
# | 4 | 7 | 5 |
#
# Iteration 100:
# f(n) = 18, g(n) = 5, h(n) = 13
# Cumulative search cost = 277
# Current node:
# | 4 | * | 6 |
# | 1 | 2 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 101:
# f(n) = 18, g(n) = 5, h(n) = 13
# Cumulative search cost = 280
# Current node:
# | 4 | 2 | 6 |
# | 1 | 5 | 8 |
# | 7 | * | 3 |
#
# Iteration 102:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 282
# Current node:
# | * | 4 | 6 |
# | 1 | 2 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 103:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 284
# Current node:
# | 1 | 4 | 6 |
# | 7 | 2 | 8 |
# | * | 5 | 3 |
#
# Iteration 104:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 287
# Current node:
# | 4 | * | 1 |
# | 8 | 2 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 105:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 290
# Current node:
# | 4 | 2 | 1 |
# | 8 | 5 | 6 |
# | 7 | * | 3 |
#
# Iteration 106:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 294
# Current node:
# | 1 | 4 | 6 |
# | 2 | * | 3 |
# | 7 | 8 | 5 |
#
# Iteration 107:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 298
# Current node:
# | 2 | 1 | 6 |
# | 7 | * | 3 |
# | 8 | 4 | 5 |
#
# Iteration 108:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 300
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 3 |
# | 8 | 5 | * |
#
# Iteration 109:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 303
# Current node:
# | 1 | 6 | 8 |
# | 2 | 5 | 4 |
# | 7 | * | 3 |
#
# Iteration 110:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 305
# Current node:
# | 2 | 6 | 3 |
# | 4 | 1 | 5 |
# | 7 | 8 | * |
#
# Iteration 111:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 309
# Current node:
# | 2 | 6 | 3 |
# | 4 | * | 1 |
# | 7 | 8 | 5 |
#
# Iteration 112:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 313
# Current node:
# | 2 | 6 | 8 |
# | 4 | * | 3 |
# | 7 | 1 | 5 |
#
# Iteration 113:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 315
# Current node:
# | 2 | 6 | 8 |
# | 4 | 1 | 3 |
# | * | 7 | 5 |
#
# Iteration 114:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 317
# Current node:
# | 4 | 2 | * |
# | 8 | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 115:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 321
# Current node:
# | 1 | 6 | 8 |
# | 2 | * | 3 |
# | 7 | 4 | 5 |
#
# Iteration 116:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 323
# Current node:
# | 1 | 6 | 8 |
# | 2 | 4 | 3 |
# | * | 7 | 5 |
#
# Iteration 117:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 325
# Current node:
# | * | 1 | 8 |
# | 2 | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 118:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 327
# Current node:
# | * | 6 | 8 |
# | 1 | 2 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 119:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 329
# Current node:
# | 1 | 6 | 8 |
# | 7 | 2 | 4 |
# | * | 5 | 3 |
#
# Iteration 120:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 331
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | * | 7 | 5 |
#
# Iteration 121:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 334
# Current node:
# | 4 | * | 2 |
# | 1 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 122:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 338
# Current node:
# | 1 | 8 | 4 |
# | 2 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 123:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 340
# Current node:
# | * | 1 | 4 |
# | 2 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 124:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 342
# Current node:
# | 1 | 4 | 6 |
# | 2 | 8 | 3 |
# | * | 7 | 5 |
#
# Iteration 125:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 344
# Current node:
# | 1 | 6 | 3 |
# | 2 | 4 | 5 |
# | 7 | 8 | * |
#
# Iteration 126:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 347
# Current node:
# | 1 | 8 | 4 |
# | 2 | 6 | * |
# | 7 | 5 | 3 |
#
# Iteration 127:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 350
# Current node:
# | 2 | 8 | 1 |
# | 4 | 3 | * |
# | 7 | 6 | 5 |
#
# Iteration 128:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 354
# Current node:
# | 4 | 2 | 6 |
# | 1 | * | 3 |
# | 7 | 8 | 5 |
#
# Iteration 129:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 356
# Current node:
# | 4 | 2 | 6 |
# | 1 | 8 | 3 |
# | * | 7 | 5 |
#
# Iteration 130:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 358
# Current node:
# | 4 | 2 | 1 |
# | 8 | 6 | 3 |
# | * | 7 | 5 |
#
# Iteration 131:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 360
# Current node:
# | * | 8 | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 132:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 362
# Current node:
# | 2 | 8 | 1 |
# | 7 | 4 | 3 |
# | * | 6 | 5 |
#
# Iteration 133:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 365
# Current node:
# | 4 | * | 1 |
# | 8 | 2 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 134:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 368
# Current node:
# | 4 | 2 | 1 |
# | * | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 135:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 371
# Current node:
# | 4 | 2 | 1 |
# | 8 | 3 | * |
# | 7 | 6 | 5 |
#
# Iteration 136:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 373
# Current node:
# | * | 1 | 3 |
# | 2 | 6 | 4 |
# | 7 | 8 | 5 |
#
# Iteration 137:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 375
# Current node:
# | 1 | 3 | * |
# | 2 | 6 | 4 |
# | 7 | 8 | 5 |
#
# Iteration 138:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 377
# Current node:
# | 1 | 6 | 3 |
# | 2 | 8 | 4 |
# | * | 7 | 5 |
#
# Iteration 139:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 379
# Current node:
# | 1 | 6 | 3 |
# | 2 | 8 | 4 |
# | 7 | 5 | * |
#
# Iteration 140:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 381
# Current node:
# | * | 6 | 3 |
# | 1 | 2 | 4 |
# | 7 | 8 | 5 |
#
# Iteration 141:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 383
# Current node:
# | 1 | 6 | 3 |
# | 7 | 2 | 4 |
# | * | 8 | 5 |
#
# Iteration 142:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 385
# Current node:
# | 2 | 1 | 3 |
# | 4 | 8 | 5 |
# | 7 | 6 | * |
#
# Iteration 143:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 389
# Current node:
# | 2 | 1 | 3 |
# | 4 | * | 8 |
# | 7 | 6 | 5 |
#
# Iteration 144:
# f(n) = 18, g(n) = 4, h(n) = 14
# Cumulative search cost = 391
# Current node:
# | 2 | 1 | * |
# | 4 | 5 | 6 |
# | 7 | 3 | 8 |
#
# Iteration 145:
# f(n) = 18, g(n) = 4, h(n) = 14
# Cumulative search cost = 395
# Current node:
# | 2 | 1 | 6 |
# | 4 | * | 5 |
# | 7 | 3 | 8 |
#
# Iteration 146:
# f(n) = 18, g(n) = 5, h(n) = 13
# Cumulative search cost = 398
# Current node:
# | 2 | 1 | 6 |
# | 7 | 8 | * |
# | 5 | 4 | 3 |
#
# Iteration 147:
# f(n) = 18, g(n) = 5, h(n) = 13
# Cumulative search cost = 401
# Current node:
# | 2 | 1 | 6 |
# | 4 | 3 | 5 |
# | 7 | * | 8 |
#
# Iteration 148:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 404
# Current node:
# | 1 | * | 6 |
# | 2 | 8 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 149:
# f(n) = 18, g(n) = 5, h(n) = 13
# Cumulative search cost = 407
# Current node:
# | 2 | * | 8 |
# | 4 | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 150:
# f(n) = 18, g(n) = 5, h(n) = 13
# Cumulative search cost = 410
# Current node:
# | 2 | 6 | 8 |
# | * | 4 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 151:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 413
# Current node:
# | 8 | * | 1 |
# | 2 | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 152:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 417
# Current node:
# | 2 | 3 | 1 |
# | 4 | * | 6 |
# | 7 | 8 | 5 |
#
# Iteration 153:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 419
# Current node:
# | * | 2 | 1 |
# | 4 | 3 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 154:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 421
# Current node:
# | * | 2 | 6 |
# | 8 | 1 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 155:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 423
# Current node:
# | 2 | 6 | * |
# | 8 | 1 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 156:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 425
# Current node:
# | 2 | 1 | 6 |
# | 8 | 7 | 3 |
# | * | 4 | 5 |
#
# Iteration 157:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 427
# Current node:
# | 2 | 1 | * |
# | 8 | 3 | 6 |
# | 4 | 7 | 5 |
#
# Iteration 158:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 429
# Current node:
# | 4 | 6 | * |
# | 1 | 2 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 159:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 431
# Current node:
# | * | 4 | 1 |
# | 8 | 2 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 160:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 433
# Current node:
# | 4 | 1 | * |
# | 8 | 2 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 161:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 436
# Current node:
# | 1 | 4 | 6 |
# | * | 2 | 3 |
# | 7 | 8 | 5 |
#
# Iteration 162:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 439
# Current node:
# | 2 | * | 3 |
# | 4 | 6 | 1 |
# | 7 | 8 | 5 |
#
# Iteration 163:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 442
# Current node:
# | 2 | 6 | 3 |
# | 4 | 8 | 1 |
# | 7 | * | 5 |
#
# Iteration 164:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 445
# Current node:
# | 2 | 6 | 3 |
# | * | 4 | 1 |
# | 7 | 8 | 5 |
#
# Iteration 165:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 448
# Current node:
# | 2 | * | 8 |
# | 4 | 6 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 166:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 451
# Current node:
# | 2 | 6 | 8 |
# | * | 4 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 167:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 454
# Current node:
# | 1 | * | 8 |
# | 2 | 6 | 3 |
# | 7 | 4 | 5 |
#
# Iteration 168:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 457
# Current node:
# | 1 | 6 | 8 |
# | * | 2 | 3 |
# | 7 | 4 | 5 |
#
# Iteration 169:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 460
# Current node:
# | 2 | 1 | 8 |
# | * | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 170:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 462
# Current node:
# | * | 4 | 2 |
# | 1 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 171:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 465
# Current node:
# | 1 | 8 | 4 |
# | * | 2 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 172:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 468
# Current node:
# | 2 | 1 | 4 |
# | * | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 173:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 470
# Current node:
# | 1 | 8 | 4 |
# | 2 | 6 | 3 |
# | 7 | 5 | * |
#
# Iteration 174:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 473
# Current node:
# | 8 | * | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 175:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 475
# Current node:
# | * | 4 | 1 |
# | 8 | 2 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 176:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 477
# Current node:
# | 4 | 1 | * |
# | 8 | 2 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 177:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 480
# Current node:
# | 2 | 1 | 3 |
# | * | 6 | 4 |
# | 7 | 8 | 5 |
#
# Iteration 178:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 483
# Current node:
# | 1 | 6 | 3 |
# | 7 | 2 | 4 |
# | 8 | * | 5 |
#
# Iteration 179:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 486
# Current node:
# | 2 | 1 | 3 |
# | * | 4 | 8 |
# | 7 | 6 | 5 |
#
# Iteration 180:
# f(n) = 18, g(n) = 5, h(n) = 13
# Cumulative search cost = 489
# Current node:
# | 2 | 1 | 6 |
# | * | 4 | 5 |
# | 7 | 3 | 8 |
#
# Iteration 181:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 491
# Current node:
# | 2 | 1 | * |
# | 7 | 8 | 6 |
# | 5 | 4 | 3 |
#
# Iteration 182:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 493
# Current node:
# | 2 | 1 | 6 |
# | 7 | 8 | 3 |
# | 5 | 4 | * |
#
# Iteration 183:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 495
# Current node:
# | 1 | 6 | * |
# | 2 | 8 | 3 |
# | 4 | 7 | 5 |
#
# Iteration 184:
# f(n) = 18, g(n) = 6, h(n) = 12
# Cumulative search cost = 497
# Current node:
# | * | 2 | 8 |
# | 4 | 6 | 1 |
# | 7 | 5 | 3 |
#
# Iteration 185:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 499
# Current node:
# | 8 | 1 | * |
# | 2 | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 186:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 502
# Current node:
# | 2 | 3 | 1 |
# | 4 | 8 | 6 |
# | 7 | * | 5 |
#
# Iteration 187:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 505
# Current node:
# | 2 | 3 | 1 |
# | * | 4 | 6 |
# | 7 | 8 | 5 |
#
# Iteration 188:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 508
# Current node:
# | 2 | 3 | 1 |
# | 4 | 6 | * |
# | 7 | 8 | 5 |
#
# Iteration 189:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 511
# Current node:
# | 2 | 6 | 3 |
# | 8 | 1 | * |
# | 4 | 7 | 5 |
#
# Iteration 190:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 513
# Current node:
# | * | 2 | 3 |
# | 4 | 6 | 1 |
# | 7 | 8 | 5 |
#
# Iteration 191:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 515
# Current node:
# | * | 2 | 8 |
# | 4 | 6 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 192:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 517
# Current node:
# | 2 | 8 | * |
# | 4 | 6 | 3 |
# | 7 | 1 | 5 |
#
# Iteration 193:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 519
# Current node:
# | 1 | 8 | * |
# | 2 | 6 | 3 |
# | 7 | 4 | 5 |
#
# Iteration 194:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 522
# Current node:
# | 1 | 4 | 2 |
# | * | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 195:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 526
# Current node:
# | 2 | 1 | 4 |
# | 8 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 196:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 529
# Current node:
# | 1 | 8 | 4 |
# | 2 | 6 | 3 |
# | 7 | * | 5 |
#
# Iteration 197:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 531
# Current node:
# | 8 | 1 | * |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 198:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 534
# Current node:
# | 4 | 1 | 3 |
# | 8 | 2 | * |
# | 7 | 6 | 5 |
#
# Iteration 199:
# f(n) = 18, g(n) = 7, h(n) = 11
# Cumulative search cost = 537
# Current node:
# | 2 | 1 | 6 |
# | 7 | 8 | 3 |
# | 5 | * | 4 |
#
# Iteration 200:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 540
# Current node:
# | 1 | 6 | 3 |
# | 2 | 8 | * |
# | 4 | 7 | 5 |
#
# Iteration 201:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 543
# Current node:
# | 2 | 8 | 3 |
# | 4 | 6 | * |
# | 7 | 1 | 5 |
#
# Iteration 202:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 546
# Current node:
# | 1 | 8 | 3 |
# | 2 | 6 | * |
# | 7 | 4 | 5 |
#
# Iteration 203:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 550
# Current node:
# | 1 | 4 | 2 |
# | 8 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 204:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 553
# Current node:
# | 2 | 1 | 4 |
# | 8 | 6 | * |
# | 7 | 5 | 3 |
#
# Iteration 205:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 557
# Current node:
# | 1 | 8 | 4 |
# | 2 | * | 3 |
# | 7 | 6 | 5 |
#
# Iteration 206:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 560
# Current node:
# | 8 | 1 | 3 |
# | 2 | 4 | * |
# | 7 | 6 | 5 |
#
# Iteration 207:
# f(n) = 18, g(n) = 8, h(n) = 10
# Cumulative search cost = 562
# Current node:
# | 2 | 1 | 6 |
# | 7 | 8 | 3 |
# | * | 5 | 4 |
#
# Iteration 208:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 565
# Current node:
# | 1 | * | 2 |
# | 8 | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 209:
# f(n) = 18, g(n) = 11, h(n) = 7
# Cumulative search cost = 568
# Current node:
# | 1 | 4 | 2 |
# | 8 | 6 | * |
# | 7 | 5 | 3 |
#
# Iteration 210:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 570
# Current node:
# | 2 | 1 | * |
# | 8 | 6 | 4 |
# | 7 | 5 | 3 |
#
# Iteration 211:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 572
# Current node:
# | 2 | 1 | 4 |
# | 8 | 6 | 3 |
# | 7 | 5 | * |
#
# Iteration 212:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 575
# Current node:
# | 1 | * | 4 |
# | 2 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 213:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 578
# Current node:
# | 1 | 8 | 4 |
# | * | 2 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 214:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 582
# Current node:
# | 8 | 1 | 3 |
# | 2 | * | 4 |
# | 7 | 6 | 5 |
#
# Iteration 215:
# f(n) = 18, g(n) = 9, h(n) = 9
# Cumulative search cost = 585
# Current node:
# | 2 | 1 | 6 |
# | * | 8 | 3 |
# | 7 | 5 | 4 |
#
# Iteration 216:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 587
# Current node:
# | 1 | 2 | * |
# | 8 | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 217:
# f(n) = 18, g(n) = 12, h(n) = 6
# Cumulative search cost = 589
# Current node:
# | 1 | 4 | 2 |
# | 8 | 6 | 3 |
# | 7 | 5 | * |
#
# Iteration 218:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 592
# Current node:
# | 2 | 1 | 4 |
# | 8 | 6 | 3 |
# | 7 | * | 5 |
#
# Iteration 219:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 595
# Current node:
# | 8 | 1 | 3 |
# | * | 2 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 220:
# f(n) = 18, g(n) = 10, h(n) = 8
# Cumulative search cost = 599
# Current node:
# | 2 | 1 | 6 |
# | 8 | * | 3 |
# | 7 | 5 | 4 |
#
# Iteration 221:
# f(n) = 18, g(n) = 13, h(n) = 5
# Cumulative search cost = 602
# Current node:
# | 1 | 4 | 2 |
# | 8 | 6 | 3 |
# | 7 | * | 5 |
#
# Iteration 222:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 606
# Current node:
# | 2 | 1 | 4 |
# | 8 | * | 3 |
# | 7 | 6 | 5 |
#
# Iteration 223:
# f(n) = 18, g(n) = 16, h(n) = 2
# Cumulative search cost = 608
# Current node:
# | * | 1 | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 224:
# f(n) = 18, g(n) = 14, h(n) = 4
# Cumulative search cost = 612
# Current node:
# | 1 | 4 | 2 |
# | 8 | * | 3 |
# | 7 | 6 | 5 |
#
# Iteration 225:
# f(n) = 18, g(n) = 17, h(n) = 1
# Cumulative search cost = 615
# Current node:
# | 1 | * | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 226:
# f(n) = 18, g(n) = 15, h(n) = 3
# Cumulative search cost = 618
# Current node:
# | 1 | * | 2 |
# | 8 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Goal node found!
# Solution found for 226 iterations of A* search. The heuristic function is Manhattan Distance.
# Search cost: 618 nodes generated

# %%
solution_astar_manhattan = get_solution(result_manhattan)
i = 1
for node in solution_astar_manhattan:
    print(f"Step {i}: f(n) = {node.f}, g(n) = {node.g}, h(n) = {node.h} \n{node.puzzle}")
    i += 1
# Out:
# Step 1: f(n) = 12, g(n) = 0, h(n) = 12
# | 2 | 1 | 6 |
# | 4 | * | 8 |
# | 7 | 5 | 3 |
#
# Step 2: f(n) = 12, g(n) = 1, h(n) = 11
# | 2 | 1 | 6 |
# | 4 | 8 | * |
# | 7 | 5 | 3 |
#
# Step 3: f(n) = 12, g(n) = 2, h(n) = 10
# | 2 | 1 | * |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Step 4: f(n) = 14, g(n) = 3, h(n) = 11
# | 2 | * | 1 |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Step 5: f(n) = 16, g(n) = 4, h(n) = 12
# | 2 | 8 | 1 |
# | 4 | * | 6 |
# | 7 | 5 | 3 |
#
# Step 6: f(n) = 16, g(n) = 5, h(n) = 11
# | 2 | 8 | 1 |
# | 4 | 6 | * |
# | 7 | 5 | 3 |
#
# Step 7: f(n) = 16, g(n) = 6, h(n) = 10
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | 5 | * |
#
# Step 8: f(n) = 16, g(n) = 7, h(n) = 9
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | * | 5 |
#
# Step 9: f(n) = 16, g(n) = 8, h(n) = 8
# | 2 | 8 | 1 |
# | 4 | * | 3 |
# | 7 | 6 | 5 |
#
# Step 10: f(n) = 16, g(n) = 9, h(n) = 7
# | 2 | 8 | 1 |
# | * | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 11: f(n) = 18, g(n) = 10, h(n) = 8
# | * | 8 | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 12: f(n) = 18, g(n) = 11, h(n) = 7
# | 8 | * | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 13: f(n) = 18, g(n) = 12, h(n) = 6
# | 8 | 1 | * |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 14: f(n) = 18, g(n) = 13, h(n) = 5
# | 8 | 1 | 3 |
# | 2 | 4 | * |
# | 7 | 6 | 5 |
#
# Step 15: f(n) = 18, g(n) = 14, h(n) = 4
# | 8 | 1 | 3 |
# | 2 | * | 4 |
# | 7 | 6 | 5 |
#
# Step 16: f(n) = 18, g(n) = 15, h(n) = 3
# | 8 | 1 | 3 |
# | * | 2 | 4 |
# | 7 | 6 | 5 |
#
# Step 17: f(n) = 18, g(n) = 16, h(n) = 2
# | * | 1 | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Step 18: f(n) = 18, g(n) = 17, h(n) = 1
# | 1 | * | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Step 19: f(n) = 18, g(n) = 18, h(n) = 0
# | 1 | 2 | 3 |
# | 8 | * | 4 |
# | 7 | 6 | 5 |

# %% [markdown]
# ### A* Search using Nilsson Sequence Score as the Heuristic

# %%
iters_nilsson, search_cost_nilsson, result_nilsson = astar_search(start_puzzle, goal_puzzle, "nilsson")
print(f"Solution found for {iters_nilsson} iterations of A* search. The heuristic function is Nilsson Sequence Score.")
print(f"Search cost: {search_cost_nilsson} nodes generated")
# Out:
# Iteration 1:
# f(n) = 54, g(n) = 0, h(n) = 54
# Nilsson heuristic-specific values: P(n) = 12, S(n) = 14
# Cumulative search cost = 4
# Current node:
# | 2 | 1 | 6 |
# | 4 | * | 8 |
# | 7 | 5 | 3 |
#
# Iteration 2:
# f(n) = 51, g(n) = 1, h(n) = 50
# Nilsson heuristic-specific values: P(n) = 11, S(n) = 13
# Cumulative search cost = 7
# Current node:
# | 2 | 1 | 6 |
# | * | 4 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 3:
# f(n) = 51, g(n) = 1, h(n) = 50
# Nilsson heuristic-specific values: P(n) = 11, S(n) = 13
# Cumulative search cost = 10
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | * |
# | 7 | 5 | 3 |
#
# Iteration 4:
# f(n) = 51, g(n) = 2, h(n) = 49
# Nilsson heuristic-specific values: P(n) = 10, S(n) = 13
# Cumulative search cost = 12
# Current node:
# | 2 | 1 | * |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 5:
# f(n) = 51, g(n) = 2, h(n) = 49
# Nilsson heuristic-specific values: P(n) = 10, S(n) = 13
# Cumulative search cost = 14
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | 3 |
# | 7 | 5 | * |
#
# Iteration 6:
# f(n) = 51, g(n) = 3, h(n) = 48
# Nilsson heuristic-specific values: P(n) = 9, S(n) = 13
# Cumulative search cost = 17
# Current node:
# | 2 | 1 | 6 |
# | 4 | 8 | 3 |
# | 7 | * | 5 |
#
# Iteration 7:
# f(n) = 53, g(n) = 1, h(n) = 52
# Nilsson heuristic-specific values: P(n) = 13, S(n) = 13
# Cumulative search cost = 20
# Current node:
# | 2 | * | 6 |
# | 4 | 1 | 8 |
# | 7 | 5 | 3 |
#
# Iteration 8:
# f(n) = 53, g(n) = 1, h(n) = 52
# Nilsson heuristic-specific values: P(n) = 13, S(n) = 13
# Cumulative search cost = 23
# Current node:
# | 2 | 1 | 6 |
# | 4 | 5 | 8 |
# | 7 | * | 3 |
#
# Iteration 9:
# f(n) = 53, g(n) = 2, h(n) = 51
# Nilsson heuristic-specific values: P(n) = 12, S(n) = 13
# Cumulative search cost = 25
# Current node:
# | 2 | 1 | 6 |
# | 7 | 4 | 8 |
# | * | 5 | 3 |
#
# Iteration 10:
# f(n) = 53, g(n) = 3, h(n) = 50
# Nilsson heuristic-specific values: P(n) = 11, S(n) = 13
# Cumulative search cost = 28
# Current node:
# | 2 | * | 1 |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 11:
# f(n) = 52, g(n) = 4, h(n) = 48
# Nilsson heuristic-specific values: P(n) = 12, S(n) = 12
# Cumulative search cost = 32
# Current node:
# | 2 | 8 | 1 |
# | 4 | * | 6 |
# | 7 | 5 | 3 |
#
# Iteration 12:
# f(n) = 49, g(n) = 5, h(n) = 44
# Nilsson heuristic-specific values: P(n) = 11, S(n) = 11
# Cumulative search cost = 35
# Current node:
# | 2 | 8 | 1 |
# | * | 4 | 6 |
# | 7 | 5 | 3 |
#
# Iteration 13:
# f(n) = 49, g(n) = 5, h(n) = 44
# Nilsson heuristic-specific values: P(n) = 11, S(n) = 11
# Cumulative search cost = 38
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | * |
# | 7 | 5 | 3 |
#
# Iteration 14:
# f(n) = 49, g(n) = 6, h(n) = 43
# Nilsson heuristic-specific values: P(n) = 10, S(n) = 11
# Cumulative search cost = 40
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | 5 | * |
#
# Iteration 15:
# f(n) = 49, g(n) = 7, h(n) = 42
# Nilsson heuristic-specific values: P(n) = 9, S(n) = 11
# Cumulative search cost = 43
# Current node:
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | * | 5 |
#
# Iteration 16:
# f(n) = 40, g(n) = 8, h(n) = 32
# Nilsson heuristic-specific values: P(n) = 8, S(n) = 8
# Cumulative search cost = 47
# Current node:
# | 2 | 8 | 1 |
# | 4 | * | 3 |
# | 7 | 6 | 5 |
#
# Iteration 17:
# f(n) = 37, g(n) = 9, h(n) = 28
# Nilsson heuristic-specific values: P(n) = 7, S(n) = 7
# Cumulative search cost = 50
# Current node:
# | 2 | 8 | 1 |
# | * | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 18:
# f(n) = 39, g(n) = 9, h(n) = 30
# Nilsson heuristic-specific values: P(n) = 9, S(n) = 7
# Cumulative search cost = 53
# Current node:
# | 2 | 8 | 1 |
# | 4 | 3 | * |
# | 7 | 6 | 5 |
#
# Iteration 19:
# f(n) = 43, g(n) = 9, h(n) = 34
# Nilsson heuristic-specific values: P(n) = 7, S(n) = 9
# Cumulative search cost = 56
# Current node:
# | 2 | * | 1 |
# | 4 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 20:
# f(n) = 43, g(n) = 10, h(n) = 33
# Nilsson heuristic-specific values: P(n) = 6, S(n) = 9
# Cumulative search cost = 58
# Current node:
# | 2 | 1 | * |
# | 4 | 8 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 21:
# f(n) = 43, g(n) = 11, h(n) = 32
# Nilsson heuristic-specific values: P(n) = 5, S(n) = 9
# Cumulative search cost = 61
# Current node:
# | 2 | 1 | 3 |
# | 4 | 8 | * |
# | 7 | 6 | 5 |
#
# Iteration 22:
# f(n) = 45, g(n) = 10, h(n) = 35
# Nilsson heuristic-specific values: P(n) = 8, S(n) = 9
# Cumulative search cost = 63
# Current node:
# | * | 8 | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 23:
# f(n) = 45, g(n) = 10, h(n) = 35
# Nilsson heuristic-specific values: P(n) = 8, S(n) = 9
# Cumulative search cost = 65
# Current node:
# | 2 | 8 | 1 |
# | 7 | 4 | 3 |
# | * | 6 | 5 |
#
# Iteration 24:
# f(n) = 45, g(n) = 11, h(n) = 34
# Nilsson heuristic-specific values: P(n) = 7, S(n) = 9
# Cumulative search cost = 68
# Current node:
# | 8 | * | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 25:
# f(n) = 45, g(n) = 12, h(n) = 33
# Nilsson heuristic-specific values: P(n) = 6, S(n) = 9
# Cumulative search cost = 70
# Current node:
# | 8 | 1 | * |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Iteration 26:
# f(n) = 45, g(n) = 13, h(n) = 32
# Nilsson heuristic-specific values: P(n) = 5, S(n) = 9
# Cumulative search cost = 73
# Current node:
# | 8 | 1 | 3 |
# | 2 | 4 | * |
# | 7 | 6 | 5 |
#
# Iteration 27:
# f(n) = 36, g(n) = 14, h(n) = 22
# Nilsson heuristic-specific values: P(n) = 4, S(n) = 6
# Cumulative search cost = 77
# Current node:
# | 8 | 1 | 3 |
# | 2 | * | 4 |
# | 7 | 6 | 5 |
#
# Iteration 28:
# f(n) = 33, g(n) = 15, h(n) = 18
# Nilsson heuristic-specific values: P(n) = 3, S(n) = 5
# Cumulative search cost = 80
# Current node:
# | 8 | 1 | 3 |
# | * | 2 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 29:
# f(n) = 33, g(n) = 16, h(n) = 17
# Nilsson heuristic-specific values: P(n) = 2, S(n) = 5
# Cumulative search cost = 82
# Current node:
# | * | 1 | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Iteration 30:
# f(n) = 21, g(n) = 17, h(n) = 4
# Nilsson heuristic-specific values: P(n) = 1, S(n) = 1
# Cumulative search cost = 85
# Current node:
# | 1 | * | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Goal node found!
# Solution found for 30 iterations of A* search. The heuristic function is Nilsson Sequence Score.
# Search cost: 85 nodes generated

# %%
solution_astar_nilsson = get_solution(result_nilsson)
i = 1
for node in solution_astar_nilsson:
    print(f"Step {i}: f(n) = {node.f}, g(n) = {node.g}, h(n) = {node.h} \n{node.puzzle}")
    i += 1
# Out:
# Step 1: f(n) = 54, g(n) = 0, h(n) = 54
# | 2 | 1 | 6 |
# | 4 | * | 8 |
# | 7 | 5 | 3 |
#
# Step 2: f(n) = 51, g(n) = 1, h(n) = 50
# | 2 | 1 | 6 |
# | 4 | 8 | * |
# | 7 | 5 | 3 |
#
# Step 3: f(n) = 51, g(n) = 2, h(n) = 49
# | 2 | 1 | * |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Step 4: f(n) = 53, g(n) = 3, h(n) = 50
# | 2 | * | 1 |
# | 4 | 8 | 6 |
# | 7 | 5 | 3 |
#
# Step 5: f(n) = 52, g(n) = 4, h(n) = 48
# | 2 | 8 | 1 |
# | 4 | * | 6 |
# | 7 | 5 | 3 |
#
# Step 6: f(n) = 49, g(n) = 5, h(n) = 44
# | 2 | 8 | 1 |
# | 4 | 6 | * |
# | 7 | 5 | 3 |
#
# Step 7: f(n) = 49, g(n) = 6, h(n) = 43
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | 5 | * |
#
# Step 8: f(n) = 49, g(n) = 7, h(n) = 42
# | 2 | 8 | 1 |
# | 4 | 6 | 3 |
# | 7 | * | 5 |
#
# Step 9: f(n) = 40, g(n) = 8, h(n) = 32
# | 2 | 8 | 1 |
# | 4 | * | 3 |
# | 7 | 6 | 5 |
#
# Step 10: f(n) = 37, g(n) = 9, h(n) = 28
# | 2 | 8 | 1 |
# | * | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 11: f(n) = 45, g(n) = 10, h(n) = 35
# | * | 8 | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 12: f(n) = 45, g(n) = 11, h(n) = 34
# | 8 | * | 1 |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 13: f(n) = 45, g(n) = 12, h(n) = 33
# | 8 | 1 | * |
# | 2 | 4 | 3 |
# | 7 | 6 | 5 |
#
# Step 14: f(n) = 45, g(n) = 13, h(n) = 32
# | 8 | 1 | 3 |
# | 2 | 4 | * |
# | 7 | 6 | 5 |
#
# Step 15: f(n) = 36, g(n) = 14, h(n) = 22
# | 8 | 1 | 3 |
# | 2 | * | 4 |
# | 7 | 6 | 5 |
#
# Step 16: f(n) = 33, g(n) = 15, h(n) = 18
# | 8 | 1 | 3 |
# | * | 2 | 4 |
# | 7 | 6 | 5 |
#
# Step 17: f(n) = 33, g(n) = 16, h(n) = 17
# | * | 1 | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Step 18: f(n) = 21, g(n) = 17, h(n) = 4
# | 1 | * | 3 |
# | 8 | 2 | 4 |
# | 7 | 6 | 5 |
#
# Step 19: f(n) = 18, g(n) = 18, h(n) = 0
# | 1 | 2 | 3 |
# | 8 | * | 4 |
# | 7 | 6 | 5 |

# %% [markdown]
# ## Sanity Checking
# Ensure that the solution by A* for each heuristic function is EXACTLY the same. Nothing should be printed after running the code block below.

# %%
solution_astar_misplaced = get_solution(result_misplaced)
solution_astar_manhattan = get_solution(result_manhattan)
solution_astar_nilsson = get_solution(result_nilsson)

for i in range(len(solution_astar_misplaced)):
    is_equal = solution_astar_misplaced[i] == solution_astar_manhattan[i] == solution_astar_nilsson[i]
    if not is_equal:
        print(f"There is an inconsistent solution among the three runs of A*")
        break
